# %% [markdown]
# # 일봉차트 만들기

# %% [markdown]
# ### Data processing

# %%
import pandas as pd
import mplfinance as mpf
import matplotlib.pyplot as plt
import time

# %%
from TickerDict import tickers

# %%
import DayChart

# %%
from pykiwoom.kiwoom import *
kiwoom = Kiwoom()

# %%
kiwoom.CommConnect(block=True)
print("블록킹 로그인 완료")
# Out:
# 블록킹 로그인 완료

# %%
sss = DayChart.StockDataProcessor(kiwoom)

# %%
sss.get_stock_code('현대힘스',tickers)
# Out:
# '460930'

# %%
df = sss.fetch_stock_data('460930','20250122')
# Out:
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}

# %%
df = sss.preprocess_data(df)

# %%
df  = sss.add_moving_averages(df)

# %%
df
# Out:
#              Open   High    Low  Close  Change  ChangeRate    Volume  \
# datetime
# 2024-11-25  14450  15140  14440  15140     690        4.78    604728
# 2024-11-26  15140  15190  14730  15190      50        0.33    404804
# 2024-11-27  15040  15500  14330  14440    -750       -4.94    678688
# 2024-11-28  14310  15890  14140  14630     190        1.32   2332620
# 2024-11-29  14630  14840  14220  14310    -320       -2.19    343664
# 2024-12-02  14370  14640  13260  13330    -980       -6.85    499515
# 2024-12-03  13210  13810  13200  13710     380        2.85    309442
# 2024-12-04  13170  13480  12780  13000    -710       -5.18    516062
# 2024-12-05  12900  13040  12360  12670    -330       -2.54    271911
# 2024-12-06  12590  12640  11560  12160    -510       -4.03    415372
# 2024-12-09  11770  11880  11000  11050   -1110       -9.13    363192
# 2024-12-10  11190  12210  11190  12080    1030        9.32    326692
# 2024-12-11  12080  12550  11750  12540     460        3.81    264062
# 2024-12-12  12610  12640  12120  12420    -120       -0.96    198214
# 2024-12-13  12420  12850  12170  12800     380        3.06    214218
# 2024-12-16  12820  12950  12590  12860      60        0.47    182519
# 2024-12-17  12860  12930  12650  12660    -200       -1.56    156861
# 2024-12-18  12600  13170  12520  12700      40        0.32    241524
# 2024-12-19  12320  13190  12260  13060     360        2.83    366688
# 2024-12-20  13180  14920  12840  13460     400        3.06   3596835
# 2024-12-23  13930  14200  13610  13690     230        1.71    774745
# 2024-12-24  13760  13940  13360  13630     -60       -0.44    292295
# 2024-12-26  14050  14660  13700  13980     350        2.57   1164584
# 2024-12-27  14080  14080  13220  13430    -550       -3.93    413371
# 2024-12-30  13490  13570  13250  13430       0        0.00    169989
# 2025-01-02  13300  13820  12880  13700     270        2.01    298710
# 2025-01-03  13720  13920  13500  13560    -140       -1.02    237531
# 2025-01-06  13460  13670  13370  13660     100        0.74    170214
# 2025-01-07  13850  14980  13760  14410     750        5.49   1872613
# 2025-01-08  14630  14640  14220  14520     110        0.76    631843
# 2025-01-09  14700  14700  14150  14520       0        0.00    328253
# 2025-01-10  14560  18450  14420  17800    3280       22.59  21280011
# 2025-01-13  18020  18020  16960  16960    -840       -4.72   2785962
# 2025-01-14  16940  20250  16850  18490    1530        9.02  17955440
# 2025-01-15  18670  19430  18400  18490       0        0.00   3884488
# 2025-01-16  18860  18900  18200  18900     410        2.22   1255764
# 2025-01-17  18660  19300  18510  18810     -90       -0.48   2034230
# 2025-01-20  20650  22350  19820  20100    1290        6.86   7974403
# 2025-01-21  20150  21300  19960  20650     550        2.74   2750952
# 2025-01-22  20750  20850  20000  20150    -500       -2.42   1196511
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 
# 2025-01-07               338  13695.0  13064.0
# 2025-01-08               292  13801.0  13182.0
# 2025-01-09               -12  13884.0  13355.5
# 2025-01-10             -1995  14301.0  13641.5
# 2025-01-13              2276  14599.0  13862.5
# 2025-01-14             -1750  15105.0  14166.0
# 2025-01-15              1725  15611.0  14450.5
# 2025-01-16               153  16131.0  14752.5
# 2025-01-17                -9  16656.0  15060.0
# 2025-01-20              -205  17300.0  15430.0
# 2025-01-21              -514  17924.0  15809.5
# 2025-01-22               507  18487.0  16144.0

# %%
sss3 = sss.plot_candlestick(df)

# %%
# Import the dictionary from TickerDict.py

from TickerDict import tickers  # Correctly imports the tickers variable

 # Use tickers
종목명 = input("Enter 종목명(e.g., 삼성전자): ")
date = input("Enter 기준일자 (e.g., 20250119): ")
if 종목명 in tickers:
    code = tickers[종목명]
    print(f"종목명: {종목명}, 종목코드: {tickers[종목명]}")
else:
    print(f"종목명 '{종목명}' not found.")
# Out:
# Enter 종목명(e.g., 삼성전자):  삼성전자
# Enter 기준일자 (e.g., 20250119):  20250119
# 종목명: 삼성전자, 종목코드: 005930

# %%
code
# Out:
# '460930'

# %%
df = kiwoom.block_request("opt10086",
                          종목코드=code,
                          기준일자=date,
                          표시구분=1,
                          output="일별주가요청",
                          next=1)
df
# Out:
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}
#           날짜      시가      고가      저가      종가    전일비     등락률       거래량  금액(백만)  \
# 0   20250122  +20750  +20850  -20000  -20150   -500   -2.42   1149573   23445
# 1   20250121  +20150  +21300  -19960  +20650   +550   +2.74   2750952   56768
# 2   20250120  +20650  +22350  +19820  +20100  +1290   +6.86   7974403  168408
# 3   20250117  -18660  +19300  -18510  -18810    -90   -0.48   2034230   38974
# 4   20250116  +18860  +18900  -18200  +18900   +410   +2.22   1255764   23310
# 5   20250115  +18670  +19430  -18400   18490      0    0.00   3884488   73462
# 6   20250114  -16940  +20250  -16850  +18490  +1530   +9.02  17955440  341744
# 7   20250113  +18020  +18020  -16960  -16960   -840   -4.72   2785962   48440
# 8   20250110  +14560  +18450  -14420  +17800  +3280  +22.59  21280011  370661
# 9   20250109  +14700  +14700  -14150   14520      0    0.00    328253    4729
# 10  20250108  +14630  +14640  -14220  +14520   +110   +0.76    631843    9121
# 11  20250107  +13850  +14980  +13760  +14410   +750   +5.49   1872613   27100
# 12  20250106  -13460  +13670  -13370  +13660   +100   +0.74    170214    2306
# 13  20250103  +13720  +13920  -13500  -13560   -140   -1.02    237531    3234
# 14  20250102  -13300  +13820  -12880  +13700   +270   +2.01    298710    4043
# 15  20241230  +13490  +13570  -13250   13430      0    0.00    169989    2277
# 16  20241227  +14080  +14080  -13220  -13430   -550   -3.93    413371    5619
# 17  20241226  +14050  +14660  +13700  +13980   +350   +2.57   1164584   16454
# 18  20241224  +13760  +13940  -13360  -13630    -60   -0.44    292295    3964
# 19  20241223  +13930  +14200  +13610  +13690   +230   +1.71    774745   10755
#
#      신용비  ...      외인수량     외국계    프로그램    외인비   외인보유   외인비중     외인순매수  기관순매수  \
# 0   0.00  ...         0    --45   --492  +0.38  +0.38  +0.38         0    --4
# 1   2.67  ...    +26086    +198    +503  +0.38  +0.38  +0.38    +26086   --15
# 2   2.76  ...    +24751    +335    +386  +0.31  +0.31  +0.31    +24751   --65
# 3   2.61  ...     +7424     +29    +131  +0.24  +0.24  +0.24     +7424    +79
# 4   2.44  ...    --6900    --18   --145  +0.22  +0.22  +0.22    --6900    +13
# 5   2.47  ...  --105437  --1819  --2126  +0.24  +0.24  +0.24  --105437   --20
# 6   2.14  ...   +109466   +1991   +1893  +0.54  +0.54  +0.54   +109466    +13
# 7   1.46  ...  --126328  --2135  --2280  +0.23  +0.23  +0.23  --126328    --6
# 8   1.53  ...   +120867   +2062   +2070  +0.58  +0.58  +0.58   +120867    --1
# 9   1.52  ...     +1536     +79     +21  +0.24  +0.24  +0.24     +1536     +1
# 10  1.33  ...   --22450   --303   --330  +0.24  +0.24  +0.24   --22450      0
# 11  1.33  ...   --14278   --173   --216  +0.30  +0.30  +0.30   --14278      0
# 12  1.29  ...    +16591    +117    +224  +0.34  +0.34  +0.34    +16591      0
# 13  1.33  ...   --42198   --221   --576  +0.30  +0.30  +0.30   --42198     +1
# 14  1.32  ...    +34165    +133    +461  +0.41  +0.41  +0.41    +34165     +6
# 15  1.30  ...    +27835    +147    +372  +0.32  +0.32  +0.32    +27835     +4
# 16  1.24  ...    --8745    --21   --126  +0.24  +0.24  +0.24    --8745    --1
# 17  1.27  ...   --49827   --327   --705  +0.26  +0.26  +0.26   --49827     +4
# 18  1.18  ...    +25676    +202    +342  +0.40  +0.40  +0.40    +25676   --50
# 19  0.84  ...   --36445   --247   --521  +0.33  +0.33  +0.33   --36445  --164
#
#      개인순매수 신용잔고율
# 0     +520  0.00
# 1    --514  2.67
# 2    --205  2.76
# 3      --9  2.61
# 4     +153  2.44
# 5    +1725  2.47
# 6   --1750  2.14
# 7    +2276  1.46
# 8   --1995  1.53
# 9     --12  1.52
# 10    +292  1.33
# 11    +338  1.33
# 12   --226  1.29
# 13    +560  1.33
# 14   --503  1.32
# 15   --378  1.30
# 16    +138  1.24
# 17    +777  1.27
# 18   --304  1.18
# 19    +681  0.84
#
# [20 rows x 22 columns]

# %%
dfs = []
df = kiwoom.block_request("opt10086",
                          종목코드=code,
                          기준일자=date,
                          표시구분=1,
                          output="일별주가요청",
                          next=1)

dfs.append(df)
a=0
while a<2:
    a = a+1
    df = kiwoom.block_request("opt10086",
                          종목코드=code,
                          기준일자=date,
                          표시구분=1,
                          output="일별주가요청",
                          next=2)
    dfs.append(df)
    time.sleep(1)
    
df = pd.concat(dfs, ignore_index=True)
# Out:
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}

# %%
df = df.drop(columns=["신용비", "개인", "기관", "외인수량", "외국계", "외인비", "외인보유", "외인비중", "신용잔고율"])

# %%
df.dtypes
# Out:
# 날짜        object
# 시가        object
# 고가        object
# 저가        object
# 종가        object
# 전일비       object
# 등락률       object
# 거래량       object
# 금액(백만)    object
# 신용비       object
# 개인        object
# 기관        object
# 외인수량      object
# 외국계       object
# 프로그램      object
# 외인비       object
# 외인보유      object
# 외인비중      object
# 외인순매수     object
# 기관순매수     object
# 개인순매수     object
# 신용잔고율     object
# dtype: object

# %%
df.dtypes
# Out:
# 날짜        object
# 시가        object
# 고가        object
# 저가        object
# 종가        object
# 전일비       object
# 등락률       object
# 거래량       object
# 금액(백만)    object
# 프로그램      object
# 외인순매수     object
# 기관순매수     object
# 개인순매수     object
# dtype: object

# %%
df.head()
# Out:
#          날짜      시가      고가      저가      종가    전일비    등락률      거래량  금액(백만)  \
# 0  20250122  +20750  +20850  -20000  -20150   -500  -2.42  1149573   23445
# 1  20250121  +20150  +21300  -19960  +20650   +550  +2.74  2750952   56768
# 2  20250120  +20650  +22350  +19820  +20100  +1290  +6.86  7974403  168408
# 3  20250117  -18660  +19300  -18510  -18810    -90  -0.48  2034230   38974
# 4  20250116  +18860  +18900  -18200  +18900   +410  +2.22  1255764   23310
#
#     프로그램   외인순매수 기관순매수  개인순매수
# 0  --492       0   --4   +520
# 1   +503  +26086  --15  --514
# 2   +386  +24751  --65  --205
# 3   +131   +7424   +79    --9
# 4  --145  --6900   +13   +153

# %%
columns_to_replace = ['프로그램','외인순매수','기관순매수','개인순매수']
df[columns_to_replace] = df[columns_to_replace].replace("--", "-", regex=True)
df.head()
# Out:
#          날짜      시가      고가      저가      종가    전일비    등락률      거래량  금액(백만)  \
# 0  20250122  +20750  +20850  -20000  -20150   -500  -2.42  1149573   23445
# 1  20250121  +20150  +21300  -19960  +20650   +550  +2.74  2750952   56768
# 2  20250120  +20650  +22350  +19820  +20100  +1290  +6.86  7974403  168408
# 3  20250117  -18660  +19300  -18510  -18810    -90  -0.48  2034230   38974
# 4  20250116  +18860  +18900  -18200  +18900   +410  +2.22  1255764   23310
#
#    프로그램   외인순매수 기관순매수 개인순매수
# 0  -492       0    -4  +520
# 1  +503  +26086   -15  -514
# 2  +386  +24751   -65  -205
# 3  +131   +7424   +79    -9
# 4  -145   -6900   +13  +153

# %%
df.dtypes
# Out:
# 날짜        object
# 시가        object
# 고가        object
# 저가        object
# 종가        object
# 전일비       object
# 등락률       object
# 거래량       object
# 금액(백만)    object
# 프로그램      object
# 외인순매수     object
# 기관순매수     object
# 개인순매수     object
# dtype: object

# %%
# Change the data type of '날짜' to datetime
df["날짜"] = pd.to_datetime(df["날짜"], format="%Y%m%d")

# Change the data type of '등락률' to float
df["등락률"] = df["등락률"].astype(float)

# Change all other columns to int
columns_to_convert = df.columns.difference(["날짜", "등락률"])
df[columns_to_convert] = df[columns_to_convert].astype(int)

# %%
# Divide the values in the "금액" column by 100
df["금액(백만)"] = df["금액(백만)"] / 100
# Rename the "금액" column to "금액(억)"
df.rename(columns={"금액(백만)": "금액(억)"}, inplace=True)

# %%
df.dtypes
# Out:
# 날짜       datetime64[ns]
# 시가                int32
# 고가                int32
# 저가                int32
# 종가                int32
# 전일비               int32
# 등락률             float64
# 거래량               int32
# 금액(억)           float64
# 프로그램              int32
# 외인순매수             int32
# 기관순매수             int32
# 개인순매수             int32
# dtype: object

# %%
# 23   343   19242      1   -271
# 24  -376  -25924     -1    311
# 25    61   -1931      2      8
# 26   749   55426      0   -782
# 27   620   47933     -1   -771
# 28   803   63689      0   -820
# 29   509   43160      0   -554
# 30   676   60035      4   -623
# 31   414   35380     -7   -370
# 32   -25   -1879      0     24
# 33  -315  -25339      1    326
# 34  -101   -8247      9    104
# 35  -191  -14968     -1    185
# 36  -152  -10468    -15    111
# 37  -214  -15674    -15    328
# 38   186   14156    144   -317
# 39 -2025 -145061    397   1643
# 40  -521  -36445   -164    681
# 41   342   25676    -50   -304
# 42  -705  -49827      4    777
# 43  -126   -8745     -1    138
# 44   372   27835      4   -378
# 45   461   34165      6   -503
# 46  -576  -42198      1    560
# 47   224   16591      0   -226
# 48  -216  -14278      0    338
# 49  -330  -22450      0    292
# 50    21    1536      1    -12
# 51  2070  120867     -1  -1995
# 52 -2280 -126328     -6   2276
# 53  1893  109466     13  -1750
# 54 -2126 -105437    -20   1725
# 55  -145   -6900     13    153
# 56   131    7424     79     -9
# 57   386   24751    -65   -205
# 58   503   26086    -15   -514
# 59  -492       0     -4    520

# %% [markdown]
# ### mplfinance library

# %%
df.dtypes
# Out:
# 날짜       datetime64[ns]
# 시가                int32
# 고가                int32
# 저가                int32
# 종가                int32
# 전일비               int32
# 등락률             float64
# 거래량               int32
# 금액(억)           float64
# 프로그램              int32
# 외인순매수             int32
# 기관순매수             int32
# 개인순매수             int32
# dtype: object

# %%
# Rename columns
df = df.rename(columns={
    "날짜": "datetime",
    "시가": "Open",
    "고가": "High",
    "저가": "Low",
    "종가": "Close",
    "거래량": "Volume",       # Optional if volume is available
    "전일비": "Change",       # Change compared to the previous day
    "등락률": "ChangeRate",   # Change rate (percentage)
    "금액(억)": "TradingValue", # Trading value
    "프로그램": "Program",    # Program trading
    "외인순매수": "ForeignNetBuy", # Foreign net buy
    "기관순매수": "InstitutionNetBuy", # Institution net buy
    "개인순매수": "IndividualNetBuy"  # Individual net buy
})

# Check the DataFrame to ensure the columns are renamed correctly

# %%
df.head()
# Out:
#     datetime  Open   High   Low  Close  Change  ChangeRate  Volume  \
# 0 2024-10-28 -9780   9920 -9750   9900      60        0.61   77522
# 1 2024-10-29  9920  10120 -9850  10090     190        1.92   68913
# 2 2024-10-30 -9990  10120 -9890  -9940    -150       -1.49   54434
# 3 2024-10-31 -9930   9990 -9580   9960      20        0.20   89128
# 4 2024-11-01  9980   9980 -9710  -9860    -100       -1.00   58121
#
#    TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  IndividualNetBuy
# 0          7.64      388          39339                  1              -397
# 1          6.86      136          13675                -40               -88
# 2          5.42      -56          -5616                -41                84
# 3          8.72      180          18219                  0              -181
# 4          5.69      -21          -2228                -67                88

# %%
# DataFrame의 인덱스를 날짜로 설정 (mplfinance가 요구하는 포맷)
df.set_index("datetime", inplace=True)

# %%
df.head()
# Out:
#             Open   High   Low  Close  Change  ChangeRate  Volume  \
# datetime
# 2024-10-28 -9780   9920 -9750   9900      60        0.61   77522
# 2024-10-29  9920  10120 -9850  10090     190        1.92   68913
# 2024-10-30 -9990  10120 -9890  -9940    -150       -1.49   54434
# 2024-10-31 -9930   9990 -9580   9960      20        0.20   89128
# 2024-11-01  9980   9980 -9710  -9860    -100       -1.00   58121
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 2024-10-28          7.64      388          39339                  1
# 2024-10-29          6.86      136          13675                -40
# 2024-10-30          5.42      -56          -5616                -41
# 2024-10-31          8.72      180          18219                  0
# 2024-11-01          5.69      -21          -2228                -67
#
#             IndividualNetBuy
# datetime
# 2024-10-28              -397
# 2024-10-29               -88
# 2024-10-30                84
# 2024-10-31              -181
# 2024-11-01                88

# %%
# Apply absolute value transformation to specific columns
columns_to_transform = ["Open", "High", "Low", "Close"]
df[columns_to_transform] = df[columns_to_transform].abs()

# %%
df.head()
# Out:
#             Open   High   Low  Close  Change  ChangeRate  Volume  \
# datetime
# 2024-10-28  9780   9920  9750   9900      60        0.61   77522
# 2024-10-29  9920  10120  9850  10090     190        1.92   68913
# 2024-10-30  9990  10120  9890   9940    -150       -1.49   54434
# 2024-10-31  9930   9990  9580   9960      20        0.20   89128
# 2024-11-01  9980   9980  9710   9860    -100       -1.00   58121
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 2024-10-28          7.64      388          39339                  1
# 2024-10-29          6.86      136          13675                -40
# 2024-10-30          5.42      -56          -5616                -41
# 2024-10-31          8.72      180          18219                  0
# 2024-11-01          5.69      -21          -2228                -67
#
#             IndividualNetBuy
# datetime
# 2024-10-28              -397
# 2024-10-29               -88
# 2024-10-30                84
# 2024-10-31              -181
# 2024-11-01                88

# %%
# 2. 봉차트 그리기
mpf.plot(
    df,
    type="candle",  # 봉차트
    style="charles",  # 스타일 (다양한 스타일 지원)
    title="Stock Name",  # 차트 제목
    ylabel="Price",  # y축 라벨
    volume=False  # 거래량 표시 여부 (False로 설정)
)

# %%
# Custom market colors
custom_colors = mpf.make_marketcolors(
    up="red",    # Custom color for up (e.g., blue)
    down="blue", # Custom color for down (e.g., orange)
    wick="black",  # Wick color
    edge="black"   # Edge color
)

# Custom style with the market colors
custom_style = mpf.make_mpf_style(
    marketcolors=custom_colors, 
    gridcolor="gray",  # Gridline color
    gridstyle="--"     # Gridline style
)


mpf.plot(
    df,
    type="candle",
    style=custom_style,
    title="Name",
    ylabel="Price",
    volume=True  
)

# %%
df.head()
# Out:
#             Open   High   Low  Close  Change  ChangeRate  Volume  \
# datetime
# 2024-10-28  9780   9920  9750   9900      60        0.61   77522
# 2024-10-29  9920  10120  9850  10090     190        1.92   68913
# 2024-10-30  9990  10120  9890   9940    -150       -1.49   54434
# 2024-10-31  9930   9990  9580   9960      20        0.20   89128
# 2024-11-01  9980   9980  9710   9860    -100       -1.00   58121
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 2024-10-28          7.64      388          39339                  1
# 2024-10-29          6.86      136          13675                -40
# 2024-10-30          5.42      -56          -5616                -41
# 2024-10-31          8.72      180          18219                  0
# 2024-11-01          5.69      -21          -2228                -67
#
#             IndividualNetBuy
# datetime
# 2024-10-28              -397
# 2024-10-29               -88
# 2024-10-30                84
# 2024-10-31              -181
# 2024-11-01                88

# %%
df['10DMA']=df['Close'].rolling(window=10).mean()
df['20DMA']=df['Close'].rolling(window=20).mean()
df['10DMA']
# Out:
# datetime
# 2024-10-28        NaN
# 2024-10-29        NaN
# 2024-10-30        NaN
# 2024-10-31        NaN
# 2024-11-01        NaN
# 2024-11-04        NaN
# 2024-11-05        NaN
# 2024-11-06        NaN
# 2024-11-07        NaN
# 2024-11-08    10834.0
# 2024-11-11    11502.0
# 2024-11-12    12152.0
# 2024-11-13    12603.0
# 2024-11-14    13097.0
# 2024-11-15    13531.0
# 2024-11-18    13980.0
# 2024-11-19    14447.0
# 2024-11-20    14882.0
# 2024-11-21    14940.0
# 2024-11-22    14924.0
# 2024-11-25    14780.0
# 2024-11-26    14640.0
# 2024-11-27    14639.0
# 2024-11-28    14612.0
# 2024-11-29    14623.0
# 2024-12-02    14496.0
# 2024-12-03    14382.0
# 2024-12-04    14217.0
# 2024-12-05    14087.0
# 2024-12-06    13858.0
# 2024-12-09    13449.0
# 2024-12-10    13138.0
# 2024-12-11    12948.0
# 2024-12-12    12727.0
# 2024-12-13    12576.0
# 2024-12-16    12529.0
# 2024-12-17    12424.0
# 2024-12-18    12394.0
# 2024-12-19    12433.0
# 2024-12-20    12563.0
# 2024-12-23    12827.0
# 2024-12-24    12982.0
# 2024-12-26    13126.0
# 2024-12-27    13227.0
# 2024-12-30    13290.0
# 2025-01-02    13374.0
# 2025-01-03    13464.0
# 2025-01-06    13560.0
# 2025-01-07    13695.0
# 2025-01-08    13801.0
# 2025-01-09    13884.0
# 2025-01-10    14301.0
# 2025-01-13    14599.0
# 2025-01-14    15105.0
# 2025-01-15    15611.0
# 2025-01-16    16131.0
# 2025-01-17    16656.0
# 2025-01-20    17300.0
# 2025-01-21    17924.0
# 2025-01-22    18487.0
# Name: 10DMA, dtype: float64

# %%
# Calculate 10-day and 20-day moving averages
df["10DMA"] = df["Close"].rolling(window=10).mean()
df["20DMA"] = df["Close"].rolling(window=20).mean()

# %%
# Custom market colors
custom_colors = mpf.make_marketcolors(
    up="red",    # Custom color for up (e.g., blue)
    down="blue", # Custom color for down (e.g., orange)
    wick="black",  # Wick color
    edge="black"   # Edge color
)

# Custom style with the market colors
custom_style = mpf.make_mpf_style(
    marketcolors=custom_colors, 
    gridcolor="gray",  # Gridline color
    gridstyle="--"     # Gridline style
)

# Define the additional plots for the moving averages
add_plots = [
    mpf.make_addplot(df["10DMA"], color="navy", width=1.0, linestyle="solid"),
    mpf.make_addplot(df["20DMA"], color="gold", width=2.0, linestyle="solid"),
    mpf.make_addplot(df["TradingValue"], panel=1, color="gray", type="bar")
]


mpf.plot(
    df,
    type="candle",
    style=custom_style,
    title="Name",
    ylabel="Price",
    ylabel_lower="Trading Value",
    volume=False,
    addplot=add_plots,
)

# %%
import sys

# Print the list of paths
for path in sys.path:
    print(path)
# Out:
# C:\anaconda3\envs\py39_32\python39.zip
# C:\anaconda3\envs\py39_32\DLLs
# C:\anaconda3\envs\py39_32\lib
# C:\anaconda3\envs\py39_32
#
# C:\anaconda3\envs\py39_32\lib\site-packages
# C:\anaconda3\envs\py39_32\lib\site-packages\locket-0.2.1-py3.9.egg
# C:\anaconda3\envs\py39_32\lib\site-packages\win32
# C:\anaconda3\envs\py39_32\lib\site-packages\win32\lib
# C:\anaconda3\envs\py39_32\lib\site-packages\Pythonwin

# %% [markdown]
# ### TickerDict.py generation {stock name: stock code}

# %%
# Get tickers for KOSPI and KOSDAQ
kospi_tickers = kiwoom.GetCodeListByMarket("0")  # KOSPI
kosdaq_tickers = kiwoom.GetCodeListByMarket("10")  # KOSDAQ

# Create dictionaries for stock names and codes
kospi_dict = {kiwoom.GetMasterCodeName(code): code for code in kospi_tickers}
kosdaq_dict = {kiwoom.GetMasterCodeName(code): code for code in kosdaq_tickers}

# %%
# Combine both dictionaries into one
all_tickers = {**kospi_dict, **kosdaq_dict}

# %%
len(kospi_tickers)
# Out:
# 2312

# %%
len(kospi_dict)
# Out:
# 2312

# %%
len(all_tickers)
# Out:
# 4096

# %%
# Save the dictionary to a Python file
with open("TickerDict.py", "w", encoding="utf-8") as f:
    f.write("tickers = {\n")
    for name, code in all_tickers.items():
        f.write(f'    "{name}": "{code}",\n')
    f.write("}\n")

print("TickerDict.py has been created!")
# Out:
# TickerDict.py has been created!

# %%
# Let me process and analyze the uploaded notebook to clean and reorganize it.
import nbformat

# Load the uploaded notebook file
file_path = 'code.ipynb'
with open(file_path, 'r', encoding='utf-8') as file:
    notebook = nbformat.read(file, as_version=4)

# Extract cells to identify unnecessary or unorganized parts
notebook_cells = notebook['cells']
notebook_cells
# Out:
# [{'cell_type': 'markdown',
#   'id': '85ca0cd8-8ac2-460b-be95-3692591b123a',
#   'metadata': {'tags': []},
#   'source': '# 일봉차트 만들기'},
#  {'cell_type': 'markdown',
#   'id': '471f3baa-ff54-43b8-a2f9-97f457b7a30f',
#   'metadata': {},
#   'source': '### Data processing'},
#  {'cell_type': 'code',
#   'execution_count': 4,
#   'id': 'f121f45d-becd-4c0a-8f62-0ff4bbe97861',
#   'metadata': {},
#   'outputs': [],
#   'source': 'import pandas as pd'},
#  {'cell_type': 'code',
#   'execution_count': 5,
#   'id': '5cd2ec13-f121-4e0f-9da1-5140ed654fd8',
#   'metadata': {},
#   'outputs': [],
#   'source': 'import mplfinance as mpf'},
#  {'cell_type': 'code',
#   'execution_count': 6,
#   'id': '8e2f7104-80f7-4e3a-8e30-bcfe8fd526a9',
#   'metadata': {},
#   'outputs': [],
#   'source': 'import matplotlib.pyplot as plt'},
#  {'cell_type': 'code',
#   'execution_count': 48,
#   'id': 'db9c8b05-c7cd-483e-841a-c742ae1d72b8',
#   'metadata': {},
#   'outputs': [],
#   'source': 'import time'},
#  {'cell_type': 'code',
#   'execution_count': 7,
#   'id': '484431ab-10de-459e-a64a-5c2d65824d50',
#   'metadata': {},
#   'outputs': [],
#   'source': 'from pykiwoom.kiwoom import *\nkiwoom = Kiwoom()'},
#  {'cell_type': 'code',
#   'execution_count': 8,
#   'id': 'a634b811-cef7-42c9-9c4d-9e51456ed42c',
#   'metadata': {},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': '블록킹 로그인 완료\n'}],
#   'source': 'kiwoom.CommConnect(block=True)\nprint("블록킹 로그인 완료")'},
#  {'cell_type': 'code',
#   'execution_count': 58,
#   'id': '6ad3b554-8420-4322-b5ca-0b1c0ebae394',
#   'metadata': {},
#   'outputs': [{'name': 'stdin',
#     'output_type': 'stream',
#     'text': 'Enter 종목명(e.g., 삼성전자):  삼성전자\nEnter 기준일자 (e.g., 20250119):  20250119\n'},
#    {'name': 'stdout',
#     'output_type': 'stream',
#     'text': '종목명: 삼성전자, 종목코드: 005930\n'}],
#   'source': '# Import the dictionary from TickerDict.py\n\nfrom TickerDict import tickers  # Correctly imports the tickers variable\n\n # Use tickers\n종목명 = input("Enter 종목명(e.g., 삼성전자): ")\ndate = input("Enter 기준일자 (e.g., 20250119): ")\nif 종목명 in tickers:\n    code = tickers[종목명]\n    print(f"종목명: {종목명}, 종목코드: {tickers[종목명]}")\nelse:\n    print(f"종목명 \'{종목명}\' not found.")'},
#  {'cell_type': 'code',
#   'execution_count': 10,
#   'id': '23c63c74-b623-4fcd-ba33-72d8101ab17c',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': "'460930'"},
#     'execution_count': 10,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'code'},
#  {'cell_type': 'code',
#   'execution_count': 11,
#   'id': 'f56d8947-d29f-4c5d-9623-b548e24f69c6',
#   'metadata': {'collapsed': True,
#    'jupyter': {'outputs_hidden': True},
#    'tags': []},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': "{'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}\n"},
#    {'data': {'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>날짜</th>\n      <th>시가</th>\n      <th>고가</th>\n      <th>저가</th>\n      <th>종가</th>\n      <th>전일비</th>\n      <th>등락률</th>\n      <th>거래량</th>\n      <th>금액(백만)</th>\n      <th>신용비</th>\n      <th>...</th>\n      <th>외인수량</th>\n      <th>외국계</th>\n      <th>프로그램</th>\n      <th>외인비</th>\n      <th>외인보유</th>\n      <th>외인비중</th>\n      <th>외인순매수</th>\n      <th>기관순매수</th>\n      <th>개인순매수</th>\n      <th>신용잔고율</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>20250122</td>\n      <td>+20750</td>\n      <td>+20850</td>\n      <td>-20000</td>\n      <td>-20150</td>\n      <td>-500</td>\n      <td>-2.42</td>\n      <td>1149573</td>\n      <td>23445</td>\n      <td>0.00</td>\n      <td>...</td>\n      <td>0</td>\n      <td>--45</td>\n      <td>--492</td>\n      <td>+0.38</td>\n      <td>+0.38</td>\n      <td>+0.38</td>\n      <td>0</td>\n      <td>--4</td>\n      <td>+520</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>20250121</td>\n      <td>+20150</td>\n      <td>+21300</td>\n      <td>-19960</td>\n      <td>+20650</td>\n      <td>+550</td>\n      <td>+2.74</td>\n      <td>2750952</td>\n      <td>56768</td>\n      <td>2.67</td>\n      <td>...</td>\n      <td>+26086</td>\n      <td>+198</td>\n      <td>+503</td>\n      <td>+0.38</td>\n      <td>+0.38</td>\n      <td>+0.38</td>\n      <td>+26086</td>\n      <td>--15</td>\n      <td>--514</td>\n      <td>2.67</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td
20250107  +13850  +14980  +13760  +14410   +750   +5.49   1872613   27100   \n12  20250106  -13460  +13670  -13370  +13660   +100   +0.74    170214    2306   \n13  20250103  +13720  +13920  -13500  -13560   -140   -1.02    237531    3234   \n14  20250102  -13300  +13820  -12880  +13700   +270   +2.01    298710    4043   \n15  20241230  +13490  +13570  -13250   13430      0    0.00    169989    2277   \n16  20241227  +14080  +14080  -13220  -13430   -550   -3.93    413371    5619   \n17  20241226  +14050  +14660  +13700  +13980   +350   +2.57   1164584   16454   \n18  20241224  +13760  +13940  -13360  -13630    -60   -0.44    292295    3964   \n19  20241223  +13930  +14200  +13610  +13690   +230   +1.71    774745   10755   \n\n     신용비  ...      외인수량     외국계    프로그램    외인비   외인보유   외인비중     외인순매수  기관순매수  \\\n0   0.00  ...         0    --45   --492  +0.38  +0.38  +0.38         0    --4   \n1   2.67  ...    +26086    +198    +503  +0.38  +0.38  +0.38    +26086   --15   \n2   2.76  ...    +24751    +335    +386  +0.31  +0.31  +0.31    +24751   --65   \n3   2.61  ...     +7424     +29    +131  +0.24  +0.24  +0.24     +7424    +79   \n4   2.44  ...    --6900    --18   --145  +0.22  +0.22  +0.22    --6900    +13   \n5   2.47  ...  --105437  --1819  --2126  +0.24  +0.24  +0.24  --105437   --20   \n6   2.14  ...   +109466   +1991   +1893  +0.54  +0.54  +0.54   +109466    +13   \n7   1.46  ...  --126328  --2135  --2280  +0.23  +0.23  +0.23  --126328    --6   \n8   1.53  ...   +120867   +2062   +2070  +0.58  +0.58  +0.58   +120867    --1   \n9   1.52  ...     +1536     +79     +21  +0.24  +0.24  +0.24     +1536     +1   \n10  1.33  ...   --22450   --303   --330  +0.24  +0.24  +0.24   --22450      0   \n11  1.33  ...   --14278   --173   --216  +0.30  +0.30  +0.30   --14278      0   \n12  1.29  ...    +16591    +117    +224  +0.34  +0.34  +0.34    +16591      0   \n13  1.33  ...   --42198   --221   --576  +0.30  +0.30  +0.30   --42198     +1   \n14  1.32  ...    +34165    +133    +461  +0.41  +0.41  +0.41    +34165     +6   \n15  1.30  ...    +27835    +147    +372  +0.32  +0.32  +0.32    +27835     +4   \n16  1.24  ...    --8745    --21   --126  +0.24  +0.24  +0.24    --8745    --1   \n17  1.27  ...   --49827   --327   --705  +0.26  +0.26  +0.26   --49827     +4   \n18  1.18  ...    +25676    +202    +342  +0.40  +0.40  +0.40    +25676   --50   \n19  0.84  ...   --36445   --247   --521  +0.33  +0.33  +0.33   --36445  --164   \n\n     개인순매수 신용잔고율  \n0     +520  0.00  \n1    --514  2.67  \n2    --205  2.76  \n3      --9  2.61  \n4     +153  2.44  \n5    +1725  2.47  \n6   --1750  2.14  \n7    +2276  1.46  \n8   --1995  1.53  \n9     --12  1.52  \n10    +292  1.33  \n11    +338  1.33  \n12   --226  1.29  \n13    +560  1.33  \n14   --503  1.32  \n15   --378  1.30  \n16    +138  1.24  \n17    +777  1.27  \n18   --304  1.18  \n19    +681  0.84  \n\n[20 rows x 22 columns]'},
#     'execution_count': 11,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'df = kiwoom.block_request("opt10086",\n                          종목코드=code,\n                          기준일자=date,\n                          표시구분=1,\n                          output="일별주가요청",\n                          next=1)\ndf'},
#  {'cell_type': 'code',
#   'execution_count': 12,
#   'id': '19d84788-8cfb-474c-8710-f6a0855583d5',
#   'metadata': {},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': "{'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}\n{'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}\n{'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}\n"}],
#   'source': '\ndfs = []\ndf = kiwoom.block_request("opt10086",\n                          종목코드=code,\n                          기준일자=date,\n                          표시구분=1,\n                          output="일별주가요청",\n                          next=1)\n\ndfs.append(df)\na=0\nwhile a<2:\n    a = a+1\n    df = kiwoom.block_request("opt10086",\n                          종목코드=code,\n                          기준일자=date,\n                          표시구분=1,\n                          output="일별주가요청",\n                          next=2)\n    dfs.append(df)\n    time.sleep(1)\n    \ndf = pd.concat(dfs, ignore_index=True)\n'},
#  {'cell_type': 'code',
#   'execution_count': 14,
#   'id': '53924fdf-e46c-40ba-9d7e-f0ba573b1e13',
#   'metadata': {},
#   'outputs': [],
#   'source': 'df = df.drop(columns=["신용비", "개인", "기관", "외인수량", "외국계", "외인비", "외인보유", "외인비중", "신용잔고율"])'},
#  {'cell_type': 'code',
#   'execution_count': 13,
#   'id': 'c9eeaaa1-7f76-4a5e-9de7-3c5679a91791',
#   'metadata': {'tags': []},
#   'outputs': [{'data': {'text/plain': '날짜        object\n시가        object\n고가        object\n저가        object\n종가        object\n전일비       object\n등락률       object\n거래량       object\n금액(백만)    object\n신용비       object\n개인        object\n기관        object\n외인수량      object\n외국계       object\n프로그램      object\n외인비       object\n외인보유      object\n외인비중      object\n외인순매수     object\n기관순매수     object\n개인순매수     object\n신용잔고율     object\ndtype: object'},
#     'execution_count': 13,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'df.dtypes'},
#  {'cell_type': 'code',
#   'execution_count': 15,
#   'id': '7c28f1fe-57b3-4bcc-9878-5252845c131f',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': '날짜        object\n시가        object\n고가        object\n저가        object\n종가        object\n전일비       object\n등락률       object\n거래량       object\n금액(백만)    object\n프로그램      object\n외인순매수     object\n기관순매수     object\n개인순매수     object\ndtype: object'},
#     'execution_count': 15,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'df.dtypes'},
#  {'cell_type': 'code',
#   'execution_count': 16,
#   'id': 'ee65965f-295a-44da-b841-68dd14b86bdf',
#   'metadata': {},
#   'outputs': [{'data': {'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>날짜</th>\n      <th>시가</th>\n      <th>고가</th>\n      <th>저가</th>\n      <th>종가</th>\n      <th>전일비</th>\n      <th>등락률</th>\n      <th>거래량</th>\n      <th>금액(백만)</th>\n      <th>프로그램</th>\n      <th>외인순매수</th>\n      <th>기관순매수</th>\n      <th>개인순매수</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>20250122</td>\n      <td>+20750</td>\n      <td>+20850</td>\n      <td>-20000</td>\n      <td>-20150</td>\n      <td>-500</td>\n      <td>-2.42</td>\n      <td>1149573</td>\n      <td>23445</td>\n      <td>--492</td>\n      <td>0</td>\n      <td>--4</td>\n      <td>+520</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>20250121</td>\n      <td>+20150</td>\n      <td>+21300</td>\n      <td>-19960</td>\n      <td>+20650</td>\n      <td>+550</td>\n      <td>+2.74</td>\n      <td>2750952</td>\n      <td>56768</td>\n      <td>+503</td>\n      <td>+26086</td>\n      <td>--15</td>\n      <td>--514</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td
td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>20250117</td>\n      <td>-18660</td>\n      <td>+19300</td>\n      <td>-18510</td>\n      <td>-18810</td>\n      <td>-90</td>\n      <td>-0.48</td>\n      <td>2034230</td>\n      <td>38974</td>\n      <td>+131</td>\n      <td>+7424</td>\n      <td>+79</td>\n      <td>-9</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>20250116</td>\n      <td>+18860</td>\n      <td>+18900</td>\n      <td>-18200</td>\n      <td>+18900</td>\n      <td>+410</td>\n      <td>+2.22</td>\n      <td>1255764</td>\n      <td>23310</td>\n      <td>-145</td>\n      <td>-6900</td>\n      <td>+13</td>\n      <td>+153</td>\n    </tr>\n  </tbody>\n</table>\n</div>',
#      'text/plain': '         날짜      시가      고가      저가      종가    전일비    등락률      거래량  금액(백만)  \\\n0  20250122  +20750  +20850  -20000  -20150   -500  -2.42  1149573   23445   \n1  20250121  +20150  +21300  -19960  +20650   +550  +2.74  2750952   56768   \n2  20250120  +20650  +22350  +19820  +20100  +1290  +6.86  7974403  168408   \n3  20250117  -18660  +19300  -18510  -18810    -90  -0.48  2034230   38974   \n4  20250116  +18860  +18900  -18200  +18900   +410  +2.22  1255764   23310   \n\n   프로그램   외인순매수 기관순매수 개인순매수  \n0  -492       0    -4  +520  \n1  +503  +26086   -15  -514  \n2  +386  +24751   -65  -205  \n3  +131   +7424   +79    -9  \n4  -145   -6900   +13  +153  '},
#     'execution_count': 17,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'columns_to_replace = [\'프로그램\',\'외인순매수\',\'기관순매수\',\'개인순매수\']\ndf[columns_to_replace] = df[columns_to_replace].replace("--", "-", regex=True)\ndf.head()'},
#  {'cell_type': 'code',
#   'execution_count': 18,
#   'id': 'd2c9d53b-d3dd-419f-9581-2d500001e847',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': '날짜        object\n시가        object\n고가        object\n저가        object\n종가        object\n전일비       object\n등락률       object\n거래량       object\n금액(백만)    object\n프로그램      object\n외인순매수     object\n기관순매수     object\n개인순매수     object\ndtype: object'},
#     'execution_count': 18,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'df.dtypes'},
#  {'cell_type': 'code',
#   'execution_count': 19,
#   'id': '8da71601-7419-49d3-8461-aafa82e0b440',
#   'metadata': {},
#   'outputs': [],
#   'source': '# Change the data type of \'날짜\' to datetime\ndf["날짜"] = pd.to_datetime(df["날짜"], format="%Y%m%d")\n\n# Change the data type of \'등락률\' to float\ndf["등락률"] = df["등락률"].astype(float)\n\n# Change all other columns to int\ncolumns_to_convert = df.columns.difference(["날짜", "등락률"])\ndf[columns_to_convert] = df[columns_to_convert].astype(int)'},
#  {'cell_type': 'code',
#   'execution_count': 20,
#   'id': '5d25b592-6816-4c3e-bcfc-44485b7d36c4',
#   'metadata': {'tags': []},
#   'outputs': [],
#   'source': '# Divide the values in the "금액" column by 100\ndf["금액(백만)"] = df["금액(백만)"] / 100\n# Rename the "금액" column to "금액(억)"\ndf.rename(columns={"금액(백만)": "금액(억)"}, inplace=True)'},
#  {'cell_type': 'code',
#   'execution_count': 21,
#   'id': '5cefa637-4608-4d59-a4e8-3695ae98a090',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': '날짜       datetime64[ns]\n시가                int32\n고가                int32\n저가                int32\n종가                int32\n전일비               int32\n등락률             float64\n거래량               int32\n금액(억)           float64\n프로그램              int32\n외인순매수             int32\n기관순매수             int32\n개인순매수             int32\ndtype: object'},
#     'execution_count': 21,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'df

#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'df = df.iloc[::-1].reset_index(drop=True)\ndf'},
#  {'cell_type': 'markdown',
#   'id': '13c06343-2bc3-47b6-a8e9-ad36bd09fe59',
#   'metadata': {},
#   'source': '### mplfinance library'},
#  {'cell_type': 'code',
#   'execution_count': 24,
#   'id': '70cf7b74-013b-41c5-81f7-fbcba76edcd0',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': '날짜       datetime64[ns]\n시가                int32\n고가                int32\n저가                int32\n종가                int32\n전일비               int32\n등락률             float64\n거래량               int32\n금액(억)           float64\n프로그램              int32\n외인순매수             int32\n기관순매수             int32\n개인순매수             int32\ndtype: object'},
#     'execution_count': 24,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'df.dtypes'},
#  {'cell_type': 'code',
#   'execution_count': 25,
#   'id': '1405456a-38b1-49a3-a013-99616732dff0',
#   'metadata': {'tags': []},
#   'outputs': [],
#   'source': '# Rename columns\ndf = df.rename(columns={\n    "날짜": "datetime",\n    "시가": "Open",\n    "고가": "High",\n    "저가": "Low",\n    "종가": "Close",\n    "거래량": "Volume",       # Optional if volume is available\n    "전일비": "Change",       # Change compared to the previous day\n    "등락률": "ChangeRate",   # Change rate (percentage)\n    "금액(억)": "TradingValue", # Trading value\n    "프로그램": "Program",    # Program trading\n    "외인순매수": "ForeignNetBuy", # Foreign net buy\n    "기관순매수": "InstitutionNetBuy", # Institution net buy\n    "개인순매수": "IndividualNetBuy"  # Individual net buy\n})\n\n# Check the DataFrame to ensure the columns are renamed correctly\n\n'},
#  {'cell_type': 'code',
#   'execution_count': 26,
#   'id': 'e93da954-47b7-4e84-bdff-cf79e9c33496',
#   'metadata': {},
#   'outputs': [{'data': {'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>datetime</th>\n      <th>Open</th>\n      <th>High</th>\n      <th>Low</th>\n      <th>Close</th>\n      <th>Change</th>\n      <th>ChangeRate</th>\n      <th>Volume</th>\n      <th>TradingValue</th>\n      <th>Program</th>\n      <th>ForeignNetBuy</th>\n      <th>InstitutionNetBuy</th>\n      <th>IndividualNetBuy</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>2024-10-28</td>\n      <td>-9780</td>\n      <td>9920</td>\n      <td>-9750</td>\n      <td>9900</td>\n      <td>60</td>\n      <td>0.61</td>\n      <td>77522</td>\n      <td>7.64</td>\n      <td>388</td>\n      <td>39339</td>\n      <td>1</td>\n      <td>-397</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>2024-10-29</td>\n      <td>9920</td>\n      <td>10120</td>\n      <td>-9850</td>\n      <td>10090</td>\n      <td>190</td>\n      <td>1.92</td>\n      <td>68913</td>\n      <td>6.86</td>\n      <td>136</td>\n      <td>13675</td>\n      <td>-40</td>\n      <td>-88</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2024-10-30</td>\n      <td>-9990</td>\n      <td>10120</td>\n      <td>-9890</td>\n      <td>-9940</td>\n      <td>-150</td>\n      <td>-1.49</td>\n      <td>54434</td>\n      <td>5.42</td>\n      <td>-56</td>\n      <td>-5616</td>\n      <td>-41</td>\n      <td>84</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>2024-10-31</td>\n      <td>-9930</td>\n      <td>9990</td>\n      <td>-9580</td>\n      <td>9960</td>\n      <td>20</td>\n      <td>0.20</td>\n      <td>89128</td>\n      <td>8.72</td>\n      <td>180</td>\n      <td>18219</td>\n      <td>0</td>\n      <td>-181</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td
radingValue  Program  ForeignNetBuy  InstitutionNetBuy  \\\ndatetime                                                              \n2024-10-28          7.64      388          39339                  1   \n2024-10-29          6.86      136          13675                -40   \n2024-10-30          5.42      -56          -5616                -41   \n2024-10-31          8.72      180          18219                  0   \n2024-11-01          5.69      -21          -2228                -67   \n\n            IndividualNetBuy  \ndatetime                      \n2024-10-28              -397  \n2024-10-29               -88  \n2024-10-30                84  \n2024-10-31              -181  \n2024-11-01                88  '},
#     'execution_count': 30,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'df.head()'},
#  {'cell_type': 'code',
#   'execution_count': 31,
#   'id': '513813ed-5295-4d53-898a-2f294af7c15d',
#   'metadata': {'tags': []},
#   'outputs': [{'data': {'image/png': '...',
#      'text/plain': '<Figure size 800x575 with 2 Axes>'},
#     'metadata': {},
#     'output_type': 'display_data'}],
#   'source': '# 2. 봉차트 그리기\nmpf.plot(\n    df,\n    type="candle",  # 봉차트\n    style="charles",  # 스타일 (다양한 스타일 지원)\n    title="Stock Name",  # 차트 제목\n    ylabel="Price",  # y축 라벨\n    volume=False  # 거래량 표시 여부 (False로 설정)\n)'},
#  {'cell_type': 'code',
#   'execution_count': 32,
#   'id': 'b7ba24db-21c9-4f7a-942b-a33e2b814a83',
#   'metadata': {},
#   'outputs': [{'data': {'image/png': '...',
#      'text/plain': '<Figure size 800x575 with 4 Axes>'},
#     'metadata': {},
#     'output_type': 'display_data'}],
#   'source': '# Custom market colors\ncustom_colors = mpf.make_marketcolors(\n    up="red",    # Custom color for up (e.g., blue)\n    down="blue", # Custom color for down (e.g., orange)\n    wick="black",  # Wick color\n    edge="black"   # Edge color\n)\n\n# Custom style with the market colors\ncustom_style = mpf.make_mpf_style(\n    marketcolors=custom_colors, \n    gridcolor="gray",  # Gridline color\n    gridstyle="--"     # Gridline style\n)\n\n\nmpf.plot(\n    df,\n    type="candle",\n    style=custom_style,\n    title="Name",\n    ylabel="Price",\n    volume=True  \n)\n'},
#  {'cell_type': 'code',
#   'execution_count': 33,
#   'id': 'd19995b4-d69c-48fc-91df-ec38463a93a9',
#   'metadata': {},
#   'outputs': [{'data': {'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Open</th>\n      <th>High</th>\n      <th>Low</th>\n      <th>Close</th>\n      <th>Change</th>\n      <th>ChangeRate</th>\n      <th>Volume</th>\n      <th>TradingValue</th>\n      <th>Program</th>\n      <th>ForeignNetBuy</th>\n      <th>InstitutionNetBuy</th>\n      <th>IndividualNetBuy</th>\n    </tr>\n    <tr>\n      <th>datetime</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>2024-10-28</th>\n      <td>9780</td>\n      <td>9920</td>\n      <td>9750</td>\n      <td>9900</td>\n      <td>60</td>\n      <td>0.61</td>\n      <td>77522</td>\n      <td>7.64</td>\n      <td>388</td>\n      <td>39339</td>\n      <td>1</td>\n      <td>-397</td>\n    </tr>\n    <tr>\n      <th>2024-10-29</th>\n      <td>9920</td>\n      <td>10120</td>\n      <td>9850</td>\n      <td>10090</td>\n      <td>190</td>\n      <td>1.92</td>\n      <td>68913</td>\n      <td>6.86</td>\n      <td>136</td>\n      <td>13675</td>\n      <td>-40</td>\n      <td>-88</td>\n    </tr>\n    <tr>\n      <th>2024-10-30</th>\n      <td>9990</td>\n      <td>10120</td>\n      <td>9890</td>\n      <td>9940</td>\n
12-26    13126.0\n2024-12-27    13227.0\n2024-12-30    13290.0\n2025-01-02    13374.0\n2025-01-03    13464.0\n2025-01-06    13560.0\n2025-01-07    13695.0\n2025-01-08    13801.0\n2025-01-09    13884.0\n2025-01-10    14301.0\n2025-01-13    14599.0\n2025-01-14    15105.0\n2025-01-15    15611.0\n2025-01-16    16131.0\n2025-01-17    16656.0\n2025-01-20    17300.0\n2025-01-21    17924.0\n2025-01-22    18487.0\nName: 10DMA, dtype: float64'},
#     'execution_count': 34,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': "df['10DMA']=df['Close'].rolling(window=10).mean()\ndf['20DMA']=df['Close'].rolling(window=20).mean()\ndf['10DMA']"},
#  {'cell_type': 'code',
#   'execution_count': 35,
#   'id': 'f27f6caf-f2f5-4700-9e5a-dc18e874f00c',
#   'metadata': {},
#   'outputs': [],
#   'source': '# Calculate 10-day and 20-day moving averages\ndf["10DMA"] = df["Close"].rolling(window=10).mean()\ndf["20DMA"] = df["Close"].rolling(window=20).mean()'},
#  {'cell_type': 'code',
#   'execution_count': 36,
#   'id': '3fcfceaa-3b03-4103-a741-ad0a460ffdc2',
#   'metadata': {},
#   'outputs': [{'data': {'image/png': '...',
#      'text/plain': '<Figure size 800x575 with 4 Axes>'},
#     'metadata': {},
#     'output_type': 'display_data'}],
#   'source': '# Custom market colors\ncustom_colors = mpf.make_marketcolors(\n    up="red",    # Custom color for up (e.g., blue)\n    down="blue", # Custom color for down (e.g., orange)\n    wick="black",  # Wick color\n    edge="black"   # Edge color\n)\n\n# Custom style with the market colors\ncustom_style = mpf.make_mpf_style(\n    marketcolors=custom_colors, \n    gridcolor="gray",  # Gridline color\n    gridstyle="--"     # Gridline style\n)\n\n# Define the additional plots for the moving averages\nadd_plots = [\n    mpf.make_addplot(df["10DMA"], color="navy", width=1.0, linestyle="solid"),\n    mpf.make_addplot(df["20DMA"], color="gold", width=2.0, linestyle="solid"),\n    mpf.make_addplot(df["TradingValue"], panel=1, color="gray", type="bar")\n]\n\n\nmpf.plot(\n    df,\n    type="candle",\n    style=custom_style,\n    title="Name",\n    ylabel="Price",\n    ylabel_lower="Trading Value",\n    volume=False,\n    addplot=add_plots,\n)\n\n'},
#  {'cell_type': 'code',
#   'execution_count': 37,
#   'id': '468a52ea-5e54-4073-9b12-7646cbc1c4b3',
#   'metadata': {},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': 'C:\\anaconda3\\envs\\py39_32\\python39.zip\nC:\\anaconda3\\envs\\py39_32\\DLLs\nC:\\anaconda3\\envs\\py39_32\\lib\nC:\\anaconda3\\envs\\py39_32\n\nC:\\anaconda3\\envs\\py39_32\\lib\\site-packages\nC:\\anaconda3\\envs\\py39_32\\lib\\site-packages\\locket-0.2.1-py3.9.egg\nC:\\anaconda3\\envs\\py39_32\\lib\\site-packages\\win32\nC:\\anaconda3\\envs\\py39_32\\lib\\site-packages\\win32\\lib\nC:\\anaconda3\\envs\\py39_32\\lib\\site-packages\\Pythonwin\n'}],
#   'source': 'import sys\n\n# Print the list of paths\nfor path in sys.path:\n    print(path)\n'},
#  {'cell_type': 'markdown',
#   'id': 'b6293aa7-d869-488d-aae2-f3aa9c81d24b',
#   'metadata': {},
#   'source': '### TickerDict.py generation {stock name: stock code}'},
#  {'cell_type': 'code',
#   'execution_count': 38,
#   'id': '7b26ce9e-a349-411c-ac7e-a6e5e7e83135',
#   'metadata': {},
#   'outputs': [],
#   'source': '# Get tickers for KOSPI and KOSDAQ\nkospi_tickers = kiwoom.GetCodeListByMarket("0")  # KOSPI\nkosdaq_tickers = kiwoom.GetCodeListByMarket("10")  # KOSDAQ\n\n# Create dictionaries for stock names and codes\nkospi_dict = {kiwoom.GetMasterCodeName(code): code for code in kospi_tickers}\nkosdaq_dict = {kiwoom.GetMasterCodeName(code): code for code in kosdaq_tickers}'},
#  {'cell_type': 'code',
#   'execution_count': 39,
#   'id': 'af24a749-638e-4ef7-8d1c-8e67e7a562f5',
#   'metadata': {},
#   'outputs': [],
#   'source': '# Combine both dictionaries into one\nall_tickers = {**kospi_dict, **kosdaq_dict}'},
#  {'cell_type': 'code',
#   'execution_count': 40,
#   'id': 'cd4bd334-61ef-4bca-a89f-9aa019f09860',
#   'metadata': {'tags': []},
#   'outputs': [{'data': {'text/plain': '2312'},
#     'execution_count': 40,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'len(kospi_tickers)'},
#  {'cell_type': 'code',
#   'execution_count': 41,
#   'id': 'f24949b2-87d8-49f5-bafa-7a3f8df153e9',
#   'metadata': {'tags': []},
#   'outputs': [{'data': {'text/plain': '2312'},
#     'execution_count': 41,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'len(kospi_dict)'},
#  {'cell_type': 'code',
#   'execution_count': 42,
#   'id': '95f172fe-b31f-4cbd-94f5-eb5f5acfa06b',
#   'metadata': {'tags': []},
#   'outputs': [{'data': {'text/plain': '4096'},
#     'execution_count': 42,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': 'len(all_tickers)'},
#  {'cell_type': 'code',
#   'execution_count': 43,
#   'id': '3a129196-6b58-423a-92cc-663980e5261c',
#   'metadata': {},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': 'TickerDict.py has been created!\n'}],
#   'source': '# Save the dictionary to a Python file\nwith open("TickerDict.py", "w", encoding="utf-8") as f:\n    f.write("tickers = {\\n")\n    for name, code in all_tickers.items():\n        f.write(f\'    "{name}": "{code}",\\n\')\n    f.write("}\\n")\n\nprint("TickerDict.py has been created!")'},
#  {'cell_type': 'code',
#   'execution_count': None,
#   'id': '8faed04b-1ce5-4149-8d1b-db5259df5220',
#   'metadata': {},
#   'outputs': [],
#   'source': ''}]

# %%
import nbformat

# Path to the Jupyter Notebook
notebook_path = "code.ipynb"
output_path = "code_cells.txt"

# Read the notebook
with open(notebook_path, 'r', encoding='utf-8') as nb_file:
    notebook = nbformat.read(nb_file, as_version=4)

# Extract code cells
code_cells = [
    cell['source'] for cell in notebook['cells'] if cell['cell_type'] == 'code'
]

# Write the code cells to a text file
with open(output_path, 'w', encoding='utf-8') as txt_file:
    for code in code_cells:
        txt_file.write(code + '\n\n')  # Add extra line for separation

print(f"Code cells have been saved to {output_path}")
# Out:
# Code cells have been saved to code_cells.txt
