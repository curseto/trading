# %%
import import_ipynb

# %%
from PyQt5.QtWidgets import *
import sys
from kiwoom.kiwoom import *

# %%
class Ui_class():
    def __init__(self):
        print("Ui_class입니다")

# %% [markdown]
# 현재 어떤 가상환경이 활성화 되었는지 알려주는 코드

# %%
# print(f"Python executable: {sys.executable}")
# print(f"Environment path: {sys.prefix}")

# %% [markdown]
# pip install pyqtwebengine==5.12.*

# %% [markdown]
# pip install pyqt5==5.12.*

# %%
# 설치된 pyqt5 버전확인

# %%
# pip show pyqt5

# %%
# 설치된 spider 버전확인

# %%
# import spyder
# print(spyder.__version__)

# %%
# 현재 사용중인 python 버전확인

# %%
# import sys
# print(sys.version)

# %%
from PyQt5.QtWidgets import *
from kiwoom.kiwoom import *

import sys

print(sys.argv)
# Out:
# ['C:\\anaconda3\\envs\\py39_32\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\손민구\\AppData\\Roaming\\jupyter\\runtime\\kernel-1233ee6d-fc38-4e59-bd07-0e5b81d127e1.json']
