# %%
# import import_ipynb

# %% [markdown]
# ipynb파일을 import 하기위해 필요한 모듈

# %%
from ui.ui import *

class Main():
    def __init__(self):
        print("실행할 메인 클래스")
        

        Ui_class()

if __name__=="__main__": 
    
    
    
    a = Main()
# Out:
# 실행할 메인 클래스
# Ui_class입니다
# Kiwoom 클래스입니다
# ('OP_ERR_NONE', '정상처리')
# 나의 보유 계좌번호는 7025642131
