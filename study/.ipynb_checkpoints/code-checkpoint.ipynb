# %% [markdown]
# ipynb 파일을 만들었는데 Notebook does not appear to be JSON 오류가 뜰경우
# File -> new -> notebook 으로 수동으로 만들것

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -----------------
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.11
# aiosignal                          1.3.2
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            3.3.8
# astropy                            4.3.1
# asttokens                          3.0.0
# async-generator                    1.10
# async-timeout                      5.0.1
# asyncssh                           2.19.0
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           2.0.4
# Babel                              2.9.1
# backcall                           0.2.0
# backports.shutil-get-terminal-size 1.0.0
# bcrypt                             3.2.0
# beautifulsoup4                     4.10.0
# binaryornot                        0.4.4
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              24.10.0
# bleach                             4.0.0
# bokeh                              2.4.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cached-property                    1.5.2
# certifi                            2021.10.8
# cffi                               1.14.6
# chardet                            4.0.0
# charset-normalizer                 2.0.4
# click                              8.0.3
# cloudpickle                        2.0.0
# clyent                             1.2.2
# colorama                           0.4.6
# comm                               0.2.2
# comtypes                           1.1.10
# conda                              4.13.0
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.8.1
# conda-token                        0.3.0
# contextlib2                        0.6.0.post1
# cookiecutter                       1.7.2
# cryptography                       44.0.0
# cycler                             0.10.0
# Cython                             0.29.24
# cytoolz                            0.11.0
# dask                               2021.10.0
# debugpy                            1.8.11
# decorator                          5.1.0
# defusedxml                         0.7.1
# Deprecated                         1.2.15
# diff-match-patch                   20200713
# dill                               0.3.9
# distributed                        2021.10.0
# docstring-to-markdown              0.15
# docutils                           0.17.1
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# exceptiongroup                     1.2.2
# executing                          2.1.0
# fastcache                          1.1.0
# filelock                           3.3.1
# flake8                             7.1.1
# Flask                              1.1.2
# fonttools                          4.25.0
# frozenlist                         1.5.0
# fsspec                             2021.10.1
# gevent                             21.8.0
# glob2                              0.7
# greenlet                           1.1.1
# h5py                               3.2.1
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               3.2
# imageio                            2.9.0
# imagesize                          1.2.0
# import-ipynb                       0.2
# importlib_metadata                 8.5.0
# inflection                         0.5.1
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          6.29.5
# ipython                            8.18.1
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.5
# isort                              5.9.3
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.18.0
# jellyfish                          1.1.3
# Jinja2                             2.11.3
# jinja2-time                        0.2.0
# joblib                             1.1.0
# json5                              0.9.6
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter_client                     8.6.3
# jupyter-console                    6.4.0
# jupyter_core                       5.7.2
# jupyter-server                     1.4.1
# jupyterlab                         3.2.1
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.8.2
# jupyterlab-widgets                 1.0.0
# keyring                            23.1.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.37.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.4.3
# matplotlib-inline                  0.1.2
# mccabe                             0.7.0
# menuinst                           1.4.18
# mistune                            0.8.4
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.10.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multidict                          6.1.0
# multipledispatch                   0.6.0
# munkres                            1.1.4
# mypy-extensions                    0.4.3
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.6.3
# nltk                               3.6.5
# nose                               1.3.7
# notebook                           6.4.5
# numba                              0.54.1
# numexpr                            2.7.3
# numpy                              1.20.3
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.9
# packaging                          24.2
# pandas                             1.3.4
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.8.2
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.12.1
# patsy                              0.5.2
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.4.0
# pip                                21.2.4
# pkginfo                            1.7.1
# platformdirs                       4.3.6
# pluggy                             1.5.0
# ply                                3.11
# poyo                               0.5.0
# prometheus-client                  0.11.0
# prompt_toolkit                     3.0.48
# propcache                          0.2.1
# psutil                             5.8.0
# ptyprocess                         0.7.0
# pure_eval                          0.2.3
# py                                 1.10.0
# pycodestyle                        2.12.1
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.44.1
# pydocstyle                         6.3.0
# pyerfa                             2.0.0
# pyflakes                           3.2.0
# PyGithub                           2.5.0
# Pygments                           2.10.0
# PyJWT                              2.10.1
# pylint                             3.3.3
# pylint-venv                        3.0.4
# pyls-spyder                        0.4.0
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          21.0.0
# pyparsing                          3.0.4
# PyQt5                              5.15.11
# PyQt5-Qt5                          5.15.2
# PyQt5_sip                          12.16.1
# PyQtWebEngine                      5.15.7
# PyQtWebEngine-Qt5                  5.15.2
# pyreadline                         2.1
# pyrsistent                         0.18.0
# PySocks                            1.7.1
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-lsp-black                   2.0.0
# python-lsp-jsonrpc                 1.1.2
# python-lsp-server                  1.12.0
# python-slugify                     5.0.2
# pytoolconfig                       1.3.1
# pytz                               2021.3
# pyuca                              1.2
# PyWavelets                         1.1.1
# pywin32                            308
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             6.0
# pyzmq                              26.2.0
# QDarkStyle                         3.2.3
# qstylizer                          0.2.4
# QtAwesome                          1.3.1
# qtconsole                          5.6.1
# QtPy                               2.4.2
# regex                              2021.8.3
# requests                           2.26.0
# rope                               1.13.0
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.16.2
# scikit-learn                       0.24.2
# scipy                              1.6.2
# seaborn                            0.11.2
# Send2Trash                         1.8.0
# setuptools                         58.0.4
# simplegeneric                      0.8.1
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# sniffio                            1.2.0
# snowballstemmer                    2.2.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# Sphinx                             4.2.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             6.0.3
# spyder-kernels                     3.0.2
# SQLAlchemy                         1.4.22
# stack-data                         0.6.3
# statsmodels                        0.12.2
# superqt                            0.7.1
# sympy                              1.9
# tables                             3.6.1
# TBB                                0.2
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.5.0
# text-unidecode                     1.3
# textdistance                       4.2.1
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tinycss                            0.4
# tinycss2                           1.4.0
# toml                               0.10.2
# tomli                              2.2.1
# tomlkit                            0.13.2
# toolz                              0.11.1
# tornado                            6.4.2
# tqdm                               4.62.3
# traitlets                          5.14.3
# typed-ast                          1.4.3
# typing_extensions                  4.12.2
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# urllib3                            1.26.7
# watchdog                           2.1.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           2.0.2
# whatthepatch                       1.0.7
# wheel                              0.37.0
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwings                            0.24.9
# xlwt                               1.3.0
# yapf                               0.43.0
# yarl                               1.18.3
# zict                               2.0.0
# zipp                               3.21.0
# zope.event                         4.5.0
# zope.interface                     5.4.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# from PyQt5.QtWidgets import QApplication 이해하기

# %%
# 모듈 까서 클래스나 함수들 보고싶을때
import PyQt5
import os

# PyQt5 모듈의 경로 확인
pyqt5_path = os.path.dirname(PyQt5.__file__)
print("PyQt5 is installed at:", pyqt5_path)

# %%
# 파이썬의 모듈 탐색 경로 확인
import sys

for path in sys.path:
    print(path)

# %%
#QApplication 객체를 실제로 호출하면서 뭔지 확인해보기
from PyQt5.QtWidgets import QApplication

app = QApplication([])
print(app)  # 출력된 메시지 **<PyQt5.QtWidgets.QApplication object at 0x06DAA4F0>**는 Python이 QApplication 객체를 메모리에 생성했으며, 이 객체의 메모리 주소를 표시하는 디버깅 정보입니다.
# Out:
# <PyQt5.QtWidgets.QApplication object at 0x06DAA4F0>

# %%
help(QApplication)
# Out:
# Help on class QApplication in module PyQt5.QtWidgets:
#
# class QApplication(PyQt5.QtGui.QGuiApplication)
#  |  QApplication(argv: List[str])
#  |
#  |  Method resolution order:
#  |      QApplication
#  |      PyQt5.QtGui.QGuiApplication
#  |      PyQt5.QtCore.QCoreApplication
#  |      PyQt5.QtCore.QObject
#  |      sip.wrapper
#  |      sip.simplewrapper
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  aboutQt(...)
#  |      aboutQt()
#  |
#  |  activeModalWidget(...)
#  |      activeModalWidget() -> Optional[QWidget]
#  |
#  |  activePopupWidget(...)
#  |      activePopupWidget() -> Optional[QWidget]
#  |
#  |  activeWindow(...)
#  |      activeWindow() -> Optional[QWidget]
#  |
#  |  alert(...)
#  |      alert(widget: Optional[QWidget], msecs: int = 0)
#  |
#  |  allWidgets(...)
#  |      allWidgets() -> List[QWidget]
#  |
#  |  autoSipEnabled(...)
#  |      autoSipEnabled(self) -> bool
#  |
#  |  beep(...)
#  |      beep()
#  |
#  |  childEvent(...)
#  |
#  |  closeAllWindows(...)
#  |      closeAllWindows()
#  |
#  |  colorSpec(...)
#  |      colorSpec() -> int
#  |
#  |  connectNotify(...)
#  |
#  |  cursorFlashTime(...)
#  |      cursorFlashTime() -> int
#  |
#  |  customEvent(...)
#  |
#  |  desktop(...)
#  |      desktop() -> Optional[QDesktopWidget]
#  |
#  |  disconnectNotify(...)
#  |
#  |  doubleClickInterval(...)
#  |      doubleClickInterval() -> int
#  |
#  |  event(...)
#  |      event(self, a0: Optional[QEvent]) -> bool
#  |
#  |  exec(...)
#  |      exec() -> int
#  |
#  |  exec_(...)
#  |      exec_() -> int
#  |
#  |  focusChanged = <unbound PYQT_SIGNAL focusChanged(QWidget*,QWidget*)>
#  |      focusChanged(self, old: Optional[QWidget], now: Optional[QWidget]) [signal]
#  |
#  |  focusWidget(...)
#  |      focusWidget() -> Optional[QWidget]
#  |
#  |  font(...)
#  |      font() -> QFont
#  |      font(a0: Optional[QWidget]) -> QFont
#  |      font(className: Optional[str]) -> QFont
#  |
#  |  fontMetrics(...)
#  |      fontMetrics() -> QFontMetrics
#  |
#  |  globalStrut(...)
#  |      globalStrut() -> QSize
#  |
#  |  isEffectEnabled(...)
#  |      isEffectEnabled(a0: Qt.UIEffect) -> bool
#  |
#  |  isSignalConnected(...)
#  |
#  |  keyboardInputInterval(...)
#  |      keyboardInputInterval() -> int
#  |
#  |  notify(...)
#  |      notify(self, a0: Optional[QObject], a1: Optional[QEvent]) -> bool
#  |
#  |  palette(...)
#  |      palette() -> QPalette
#  |      palette(a0: Optional[QWidget]) -> QPalette
#  |      palette(className: Optional[str]) -> QPalette
#  |
#  |  receivers(...)
#  |
#  |  sender(...)
#  |
#  |  senderSignalIndex(...)
#  |
#  |  setActiveWindow(...)
#  |      setActiveWindow(act: Optional[QWidget])
#  |
#  |  setAutoSipEnabled(...)
#  |      setAutoSipEnabled(self, enabled: bool)
#  |
#  |  setColorSpec(...)
#  |      setColorSpec(a0: int)
#  |
#  |  setCursorFlashTime(...)
#  |      setCursorFlashTime(a0: int)
#  |
#  |  setDoubleClickInterval(...)
#  |      setDoubleClickInterval(a0: int)
#  |
#  |  setEffectEnabled(...)
#  |      setEffectEnabled(a0: Qt.UIEffect, enabled: bool = True)
#  |
#  |  setFont(...)
#  |      setFont(a0: QFont, className: Optional[str] = None)
#  |
#  |  setGlobalStrut(...)
#  |      setGlobalStrut(a0: QSize)
#  |
#  |  setKeyboardInputInterval(...)
#  |      setKeyboardInputInterval(a0: int)
#  |
#  |  setPalette(...)
#  |      setPalette(a0: QPalette, className: Optional[str] = None)
#  |
#  |  setStartDragDistance(...)
#  |      setStartDragDistance(l: int)
#  |
#  |  setStartDragTime(...)
#  |      setStartDragTime(ms: int)
#  |
#  |  setStyle(...)
#  |      setStyle(a0: Optional[QStyle])
#  |      setStyle(a0: Optional[str]) -> Optional[QStyle]
#  |
#  |  setStyleSheet(...)
#  |      setStyleSheet(self, sheet: Optional[str])
#  |
#  |  setWheelScrollLines(...)
#  |      setWheelScrollLines(a0: int)
#  |
#  |  setWindowIcon(...)
#  |      setWindowIcon(icon: QIcon)
#  |
#  |  startDragDistance(...)
#  |      startDragDistance() -> int
#  |
#  |  startDragTime(...)
#  |      startDragTime() -> int
#  |
#  |  style(...)
#  |      style() -> Optional[QStyle]
#  |
#  |  styleSheet(...)
#  |      styleSheet(self) -> str
#  |
#  |  timerEvent(...)
#  |
#  |  topLevelAt(...)
#  |      topLevelAt(p: QPoint) -> Optional[QWidget]
#  |      topLevelAt(x: int, y: int) -> Optional[QWidget]
#  |
#  |  topLevelWidgets(...)
#  |      topLevelWidgets() -> List[QWidget]
#  |
#  |  wheelScrollLines(...)
#  |      wheelScrollLines() -> int
#  |
#  |  widgetAt(...)
#  |      widgetAt(p: QPoint) -> Optional[QWidget]
#  |      widgetAt(x: int, y: int) -> Optional[QWidget]
#  |
#  |  windowIcon(...)
#  |      windowIcon() -> QIcon
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  ColorSpec = <class 'PyQt5.QtWidgets.QApplication.ColorSpec'>
#  |
#  |  CustomColor = 1
#  |
#  |  ManyColor = 2
#  |
#  |  NormalColor = 0
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PyQt5.QtGui.QGuiApplication:
#  |
#  |  allWindows(...)
#  |      allWindows() -> List[QWindow]
#  |
#  |  applicationDisplayName(...)
#  |      applicationDisplayName() -> str
#  |
#  |  applicationDisplayNameChanged = <unbound PYQT_SIGNAL applicationDisplayNameChanged()>
#  |      applicationDisplayNameChanged(self) [signal]
#  |
#  |  applicationState(...)
#  |      applicationState() -> Qt.ApplicationState
#  |
#  |  applicationStateChanged = <unbound PYQT_SIGNAL applicationStateChanged(Qt::ApplicationState)>
#  |      applicationStateChanged(self, state: Qt.ApplicationState) [signal]
#  |
#  |  changeOverrideCursor(...)
#  |      changeOverrideCursor(a0: Union[QCursor, Qt.CursorShape])
#  |
#  |  clipboard(...)
#  |      clipboard() -> Optional[QClipboard]
#  |
#  |  commitDataRequest = <unbound PYQT_SIGNAL commitDataRequest(QSessionManager&)>
#  |      commitDataRequest(self, sessionManager: QSessionManager) [signal]
#  |
#  |  desktopFileName(...)
#  |      desktopFileName() -> str
#  |
#  |  desktopSettingsAware(...)
#  |      desktopSettingsAware() -> bool
#  |
#  |  devicePixelRatio(...)
#  |      devicePixelRatio(self) -> float
#  |
#  |  focusObject(...)
#  |      focusObject() -> Optional[QObject]
#  |
#  |  focusObjectChanged = <unbound PYQT_SIGNAL focusObjectChanged(QObject*)>
#  |      focusObjectChanged(self, focusObject: Optional[QObject]) [signal]
#  |
#  |  focusWindow(...)
#  |      focusWindow() -> Optional[QWindow]
#  |
#  |  focusWindowChanged = <unbound PYQT_SIGNAL focusWindowChanged(QWindow*)>
#  |      focusWindowChanged(self, focusWindow: Optional[QWindow]) [signal]
#  |
#  |  fontChanged = <unbound PYQT_SIGNAL fontChanged(QFont)>
#  |      fontChanged(self, font: QFont) [signal]
#  |
#  |  fontDatabaseChanged = <unbound PYQT_SIGNAL fontDatabaseChanged()>
#  |      fontDatabaseChanged(self) [signal]
#  |
#  |  highDpiScaleFactorRoundingPolicy(...)
#  |      highDpiScaleFactorRoundingPolicy() -> Qt.HighDpiScaleFactorRoundingPolicy
#  |
#  |  inputMethod(...)
#  |      inputMethod() -> Optional[QInputMethod]
#  |
#  |  isFallbackSessionManagementEnabled(...)
#  |      isFallbackSessionManagementEnabled() -> bool
#  |
#  |  isLeftToRight(...)
#  |      isLeftToRight() -> bool
#  |
#  |  isRightToLeft(...)
#  |      isRightToLeft() -> bool
#  |
#  |  isSavingSession(...)
#  |      isSavingSession(self) -> bool
#  |
#  |  isSessionRestored(...)
#  |      isSessionRestored(self) -> bool
#  |
#  |  keyboardModifiers(...)
#  |      keyboardModifiers() -> Qt.KeyboardModifiers
#  |
#  |  lastWindowClosed = <unbound PYQT_SIGNAL lastWindowClosed()>
#  |      lastWindowClosed(self) [signal]
#  |
#  |  layoutDirection(...)
#  |      layoutDirection() -> Qt.LayoutDirection
#  |
#  |  layoutDirectionChanged = <unbound PYQT_SIGNAL layoutDirectionChanged(Qt::LayoutDirection)>
#  |      layoutDirectionChanged(self, direction: Qt.LayoutDirection) [signal]
#  |
#  |  modalWindow(...)
#  |      modalWindow() -> Optional[QWindow]
#  |
#  |  mouseButtons(...)
#  |      mouseButtons() -> Qt.MouseButtons
#  |
#  |  overrideCursor(...)
#  |      overrideCursor() -> Optional[QCursor]
#  |
#  |  paletteChanged = <unbound PYQT_SIGNAL paletteChanged(QPalette)>
#  |      paletteChanged(self, pal: QPalette) [signal]
#  |
#  |  platformName(...)
#  |      platformName() -> str
#  |
#  |  primaryScreen(...)
#  |      primaryScreen() -> Optional[QScreen]
#  |
#  |  primaryScreenChanged = <unbound PYQT_SIGNAL primaryScreenChanged(QScreen*)>
#  |      primaryScreenChanged(self, screen: Optional[QScreen]) [signal]
#  |
#  |  queryKeyboardModifiers(...)
#  |      queryKeyboardModifiers() -> Qt.KeyboardModifiers
#  |
#  |  quitOnLastWindowClosed(...)
#  |      quitOnLastWindowClosed() -> bool
#  |
#  |  restoreOverrideCursor(...)
#  |      restoreOverrideCursor()
#  |
#  |  saveStateRequest = <unbound PYQT_SIGNAL saveStateRequest(QSessionManager&)>
#  |      saveStateRequest(self, sessionManager: QSessionManager) [signal]
#  |
#  |  screenAdded = <unbound PYQT_SIGNAL screenAdded(QScreen*)>
#  |      screenAdded(self, screen: Optional[QScreen]) [signal]
#  |
#  |  screenAt(...)
#  |      screenAt(point: QPoint) -> Optional[QScreen]
#  |
#  |  screenRemoved = <unbound PYQT_SIGNAL screenRemoved(QScreen*)>
#  |      screenRemoved(self, screen: Optional[QScreen]) [signal]
#  |
#  |  screens(...)
#  |      screens() -> List[QScreen]
#  |
#  |  sessionId(...)
#  |      sessionId(self) -> str
#  |
#  |  sessionKey(...)
#  |      sessionKey(self) -> str
#  |
#  |  setApplicationDisplayName(...)
#  |      setApplicationDisplayName(name: Optional[str])
#  |
#  |  setDesktopFileName(...)
#  |      setDesktopFileName(name: Optional[str])
#  |
#  |  setDesktopSettingsAware(...)
#  |      setDesktopSettingsAware(on: bool)
#  |
#  |  setFallbackSessionManagementEnabled(...)
#  |      setFallbackSessionManagementEnabled(a0: bool)
#  |
#  |  setHighDpiScaleFactorRoundingPolicy(...)
#  |      setHighDpiScaleFactorRoundingPolicy(policy: Qt.HighDpiScaleFactorRoundingPolicy)
#  |
#  |  setLayoutDirection(...)
#  |      setLayoutDirection(direction: Qt.LayoutDirection)
#  |
#  |  setOverrideCursor(...)
#  |      setOverrideCursor(a0: Union[QCursor, Qt.CursorShape])
#  |
#  |  setQuitOnLastWindowClosed(...)
#  |      setQuitOnLastWindowClosed(quit: bool)
#  |
#  |  styleHints(...)
#  |      styleHints() -> Optional[QStyleHints]
#  |
#  |  sync(...)
#  |      sync()
#  |
#  |  topLevelWindows(...)
#  |      topLevelWindows() -> List[QWindow]
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PyQt5.QtCore.QCoreApplication:
#  |
#  |  __enter__(...)
#  |      __enter__(self) -> Any
#  |
#  |  __exit__(...)
#  |      __exit__(self, type: Any, value: Any, traceback: Any)
#  |
#  |  aboutToQuit = <unbound PYQT_SIGNAL aboutToQuit()>
#  |      aboutToQuit(self) [signal]
#  |
#  |  addLibraryPath(...)
#  |      addLibraryPath(a0: Optional[str])
#  |
#  |  applicationDirPath(...)
#  |      applicationDirPath() -> str
#  |
#  |  applicationFilePath(...)
#  |      applicationFilePath() -> str
#  |
#  |  applicationName(...)
#  |      applicationName() -> str
#  |
#  |  applicationPid(...)
#  |      applicationPid() -> int
#  |
#  |  applicationVersion(...)
#  |      applicationVersion() -> str
#  |
#  |  arguments(...)
#  |      arguments() -> List[str]
#  |
#  |  closingDown(...)
#  |      closingDown() -> bool
#  |
#  |  eventDispatcher(...)
#  |      eventDispatcher() -> Optional[QAbstractEventDispatcher]
#  |
#  |  exit(...)
#  |      exit(returnCode: int = 0)
#  |
#  |  flush(...)
#  |      flush()
#  |
#  |  hasPendingEvents(...)
#  |      hasPendingEvents() -> bool
#  |
#  |  installNativeEventFilter(...)
#  |      installNativeEventFilter(self, filterObj: Optional[QAbstractNativeEventFilter])
#  |
#  |  installTranslator(...)
#  |      installTranslator(messageFile: Optional[QTranslator]) -> bool
#  |
#  |  instance(...)
#  |      instance() -> Optional[QCoreApplication]
#  |
#  |  isQuitLockEnabled(...)
#  |      isQuitLockEnabled() -> bool
#  |
#  |  isSetuidAllowed(...)
#  |      isSetuidAllowed() -> bool
#  |
#  |  libraryPaths(...)
#  |      libraryPaths() -> List[str]
#  |
#  |  organizationDomain(...)
#  |      organizationDomain() -> str
#  |
#  |  organizationName(...)
#  |      organizationName() -> str
#  |
#  |  postEvent(...)
#  |      postEvent(receiver: Optional[QObject], event: Optional[QEvent], priority: int = Qt.EventPriority.NormalEventPriority)
#  |
#  |  processEvents(...)
#  |      processEvents(flags: Union[QEventLoop.ProcessEventsFlags, QEventLoop.ProcessEventsFlag] = QEventLoop.ProcessEventsFlag.AllEvents)
#  |      processEvents(flags: Union[QEventLoop.ProcessEventsFlags, QEventLoop.ProcessEventsFlag], maxtime: int)
#  |
#  |  quit(...)
#  |      quit()
#  |
#  |  removeLibraryPath(...)
#  |      removeLibraryPath(a0: Optional[str])
#  |
#  |  removeNativeEventFilter(...)
#  |      removeNativeEventFilter(self, filterObj: Optional[QAbstractNativeEventFilter])
#  |
#  |  removePostedEvents(...)
#  |      removePostedEvents(receiver: Optional[QObject], eventType: int = 0)
#  |
#  |  removeTranslator(...)
#  |      removeTranslator(messageFile: Optional[QTranslator]) -> bool
#  |
#  |  sendEvent(...)
#  |      sendEvent(receiver: Optional[QObject], event: Optional[QEvent]) -> bool
#  |
#  |  sendPostedEvents(...)
#  |      sendPostedEvents(receiver: Optional[QObject] = None, eventType: int = 0)
#  |
#  |  setApplicationName(...)
#  |      setApplicationName(application: Optional[str])
#  |
#  |  setApplicationVersion(...)
#  |      setApplicationVersion(version: Optional[str])
#  |
#  |  setAttribute(...)
#  |      setAttribute(attribute: Qt.ApplicationAttribute, on: bool = True)
#  |
#  |  setEventDispatcher(...)
#  |      setEventDispatcher(eventDispatcher: Optional[QAbstractEventDispatcher])
#  |
#  |  setLibraryPaths(...)
#  |      setLibraryPaths(a0: Iterable[Optional[str]])
#  |
#  |  setOrganizationDomain(...)
#  |      setOrganizationDomain(orgDomain: Optional[str])
#  |
#  |  setOrganizationName(...)
#  |      setOrganizationName(orgName: Optional[str])
#  |
#  |  setQuitLockEnabled(...)
#  |      setQuitLockEnabled(enabled: bool)
#  |
#  |  setSetuidAllowed(...)
#  |      setSetuidAllowed(allow: bool)
#  |
#  |  startingUp(...)
#  |      startingUp() -> bool
#  |
#  |  testAttribute(...)
#  |      testAttribute(attribute: Qt.ApplicationAttribute) -> bool
#  |
#  |  translate(...)
#  |      translate(context: Optional[str], sourceText: Optional[str], disambiguation: Optional[str] = None, n: int = -1) -> str
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PyQt5.QtCore.QObject:
#  |
#  |  __getattr__(...)
#  |      __getattr__(self, name: Optional[str]) -> Any
#  |
#  |  blockSignals(...)
#  |      blockSignals(self, b: bool) -> bool
#  |
#  |  children(...)
#  |      children(self) -> List[QObject]
#  |
#  |  deleteLater(...)
#  |      deleteLater(self)
#  |
#  |  destroyed = <unbound PYQT_SIGNAL destroyed(QObject*)>
#  |      destroyed(self, object: Optional[QObject] = None) [signal]
#  |
#  |  disconnect(...)
#  |      disconnect(a0: QMetaObject.Connection) -> bool
#  |      disconnect(self)
#  |
#  |  dumpObjectInfo(...)
#  |      dumpObjectInfo(self)
#  |
#  |  dumpObjectTree(...)
#  |      dumpObjectTree(self)
#  |
#  |  dynamicPropertyNames(...)
#  |      dynamicPropertyNames(self) -> List[QByteArray]
#  |
#  |  eventFilter(...)
#  |      eventFilter(self, a0: Optional[QObject], a1: Optional[QEvent]) -> bool
#  |
#  |  findChild(...)
#  |      findChild(self, type: Type[QObjectT], name: Optional[str] = '', options: Union[Qt.FindChildOptions, Qt.FindChildOption] = Qt.FindChildrenRecursively) -> QObjectT
#  |      findChild(self, types: Tuple[Type[QObjectT], ...], name: Optional[str] = '', options: Union[Qt.FindChildOptions, Qt.FindChildOption] = Qt.FindChildrenRecursively) -> QObjectT
#  |
#  |  findChildren(...)
#  |      findChildren(self, type: Type[QObjectT], name: Optional[str] = '', options: Union[Qt.FindChildOptions, Qt.FindChildOption] = Qt.FindChildrenRecursively) -> List[QObjectT]
#  |      findChildren(self, types: Tuple[Type[QObjectT], ...], name: Optional[str] = '', options: Union[Qt.FindChildOptions, Qt.FindChildOption] = Qt.FindChildrenRecursively) -> List[QObjectT]
#  |      findChildren(self, type: Type[QObjectT], regExp: QRegExp, options: Union[Qt.FindChildOptions, Qt.FindChildOption] = Qt.FindChildrenRecursively) -> List[QObjectT]
#  |      findChildren(self, types: Tuple[Type[QObjectT], ...], regExp: QRegExp, options: Union[Qt.FindChildOptions, Qt.FindChildOption] = Qt.FindChildrenRecursively) -> List[QObjectT]
#  |      findChildren(self, type: Type[QObjectT], re: QRegularExpression, options: Union[Qt.FindChildOptions, Qt.FindChildOption] = Qt.FindChildrenRecursively) -> List[QObjectT]
#  |      findChildren(self, types: Tuple[Type[QObjectT], ...], re: QRegularExpression, options: Union[Qt.FindChildOptions, Qt.FindChildOption] = Qt.FindChildrenRecursively) -> List[QObjectT]
#  |
#  |  inherits(...)
#  |      inherits(self, classname: Optional[str]) -> bool
#  |
#  |  installEventFilter(...)
#  |      installEventFilter(self, a0: Optional[QObject])
#  |
#  |  isWidgetType(...)
#  |      isWidgetType(self) -> bool
#  |
#  |  isWindowType(...)
#  |      isWindowType(self) -> bool
#  |
#  |  killTimer(...)
#  |      killTimer(self, id: int)
#  |
#  |  metaObject(...)
#  |      metaObject(self) -> Optional[QMetaObject]
#  |
#  |  moveToThread(...)
#  |      moveToThread(self, thread: Optional[QThread])
#  |
#  |  objectName(...)
#  |      objectName(self) -> str
#  |
#  |  objectNameChanged = <unbound PYQT_SIGNAL objectNameChanged(QString)>
#  |      objectNameChanged(self, objectName: Optional[str]) [signal]
#  |
#  |  parent(...)
#  |      parent(self) -> Optional[QObject]
#  |
#  |  property(...)
#  |      property(self, name: Optional[str]) -> Any
#  |
#  |  pyqtConfigure(...)
#  |      QObject.pyqtConfigure(...)
#  |
#  |      Each keyword argument is either the name of a Qt property or a Qt signal.
#  |      For properties the property is set to the given value which should be of an
#  |      appropriate type.
#  |      For signals the signal is connected to the given value which should be a
#  |      callable.
#  |
#  |  removeEventFilter(...)
#  |      removeEventFilter(self, a0: Optional[QObject])
#  |
#  |  setObjectName(...)
#  |      setObjectName(self, name: Optional[str])
#  |
#  |  setParent(...)
#  |      setParent(self, a0: Optional[QObject])
#  |
#  |  setProperty(...)
#  |      setProperty(self, name: Optional[str], value: Any) -> bool
#  |
#  |  signalsBlocked(...)
#  |      signalsBlocked(self) -> bool
#  |
#  |  startTimer(...)
#  |      startTimer(self, interval: int, timerType: Qt.TimerType = Qt.CoarseTimer) -> int
#  |
#  |  thread(...)
#  |      thread(self) -> Optional[QThread]
#  |
#  |  tr(...)
#  |      tr(self, sourceText: Optional[str], disambiguation: Optional[str] = None, n: int = -1) -> str
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from PyQt5.QtCore.QObject:
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from PyQt5.QtCore.QObject:
#  |
#  |  staticMetaObject = <PyQt5.QtCore.QMetaObject object>
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sip.simplewrapper:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from sip.simplewrapper:
#  |
#  |  __new__(*args, **kwargs) from sip.wrappertype
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from sip.simplewrapper:
#  |
#  |  __dict__

# %%
import sys 
from PyQt5.QtWidgets import *

app = QApplication(sys.argv)

# %% [markdown]
# PyQt5라는 폴더(PyQt5는 패키지임)안에
# QtWidgets.pyi라는 파일(모듈임)안에
# 모든 클래스와 함수를 가져온다는 의미(* = 모든)
#
# QApplication(sys.argv)의 의미: 객체는 생성되지만, 변수에 저장하지 않으므로 해당 객체에 접근하거나 사용할 방법이 없습니다.
# 생성된 객체는 메모리에만 존재하며, Python의 **가비지 컬렉터(Garbage Collector)**가 더 이상 참조되지 않는 객체를 자동으로 삭제할 수 있습니다.
#
# app = QApplication(sys.argv)의 의미: 생성된 객체를 변수 app에 저장합니다.
# 이후에 app 변수를 통해 객체에 접근하거나 메서드를 호출할 수 있습니다.

# %%
import sys 
from PyQt5.QtWidgets import *

app = QApplication(sys.argv)
label = QLabel("Hello PyQt")
label.show()
app.exec_()

# %%
class Kiwoom:
    def __init__(self):
        login_event_loop = None  # 지역 변수

# 인스턴스 생성
kiwoom = Kiwoom()

# login_event_loop는 __init__ 내부에서만 사용되므로 접근 불가
print(kiwoom.login_event_loop)  # AttributeError
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       6 kiwoom = Kiwoom()
#       8 # login_event_loop는 __init__ 내부에서만 사용되므로 접근 불가
# ----> 9 print(kiwoom.login_event_loop)  # AttributeError
#
# AttributeError: 'Kiwoom' object has no attribute 'login_event_loop'

# %% [markdown]
# # 일봉차트 만들기

# %% [markdown]
# ### Data processing

# %%
import pandas as pd

# %%
import mplfinance as mpf

# %%
import matplotlib.pyplot as plt

# %%
from pykiwoom.kiwoom import *
kiwoom = Kiwoom()

# %%
kiwoom.CommConnect(block=True)
print("블록킹 로그인 완료")
# Out:
# 블록킹 로그인 완료

# %%
df = kiwoom.block_request("opt10086",
                          종목코드="161580",
                          기준일자="20250119",
                          표시구분=1,
                          output="일별주가요청",
                          next=1)
# print(df["거래대금"])
df
# Out:
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}
#           날짜      시가      고가      저가      종가    전일비     등락률       거래량  금액(백만)  \
# 0   20250121  +30500  +31000  -30050  -30250   -150   -0.49    713649   21813
# 1   20250120  -30700  +31800  -29800  -30400   -650   -2.09   3192857   98482
# 2   20250117  -26500  +33400  -26150  +31050  +4450  +16.73  16791418  515105
# 3   20250116  +27850  +28400  +26450  +26600   +750   +2.90   2782632   75902
# 4   20250115  -26000  +26950  -25350  -25850   -550   -2.08   2144086   56416
# 5   20250114  +25750  +27400  +25550  +26400  +2000   +8.20   6674699  176771
# 6   20250113  -24300  +25650  -24150  -24400   -200   -0.81   1385678   34415
# 7   20250110  +25950  +26000  -24250  -24600   -100   -0.40   2298744   57663
# 8   20250109  +24500  +26800  +24000  +24700  +1800   +7.86  11911834  304366
# 9   20250108  -20800  +24050  -20800  +22900  +1650   +7.76   4686085  107534
# 10  20250107  +23500  +24600  +21250  +21250   +400   +1.92   4147588   95674
# 11  20250106  +20650  +21200  -20400  +20850   +400   +1.96    908697   19294
# 12  20250103  +20400  +20700  -19890  +20450   +250   +1.24    747986   15196
# 13  20250102  +18440  +20350  -18210  +20200  +1950  +10.68    826122   16116
# 14  20241230  -18280  +18400  -17970  -18250    -80   -0.44    271138    4948
# 15  20241227  -18560  +19130  -17910  -18330   -400   -2.14    453142    8378
# 16  20241226  +18730  +19420  -18580  +18730    +30   +0.16    555610   10535
# 17  20241224  +20100  +20400  -18640  -18700   -810   -4.15    850225   16579
# 18  20241223  +19420  +19890  -19090  +19510   +270   +1.40    608978   11899
# 19  20241220  +20350  +21150  -19060  -19240   -910   -4.52   1609364   32281
#
#      신용비  ...      외인수량      외국계     프로그램    외인비   외인보유   외인비중     외인순매수  \
# 0   0.00  ...         0   --1682   --2102  +1.32  +1.32  +1.32         0
# 1   6.44  ...  --371717  --11048  --11785  +1.32  +1.32  +1.32  --371717
# 2   6.26  ...   +653560   +19307   +16367  +2.95  +2.95  +2.95   +653560
# 3   6.21  ...   --15172    --309     --77  +0.09  +0.09  +0.09   --15172
# 4   6.51  ...   --60450      +40   --2039  +0.16  +0.16  +0.16   --60450
# 5   6.60  ...    +59559    --141    +1553  +0.42  +0.42  +0.42    +59559
# 6   6.69  ...     +8642     --95    --168  +0.16  +0.16  +0.16     +8642
# 7   5.61  ...   --90452   --1304   --2015  +0.12  +0.12  +0.12   --90452
# 8   5.46  ...   +118497    +2958    +2517  +0.52  +0.52  +0.52   +118497
# 9   5.11  ...         0    --501       +7   0.00   0.00   0.00         0
# 10  5.15  ...   --88385    --342   --2580   0.00   0.00   0.00   --88385
# 11  4.99  ...   --47770    --415    --920  +0.39  +0.39  +0.39   --47770
# 12  4.92  ...   --63911    --185   --1262  +0.60  +0.60  +0.60   --63911
# 13  4.90  ...    +58790    --612    +1733  +0.88  +0.88  +0.88    +58790
# 14  4.99  ...    +14073      +45     +290  +0.62  +0.62  +0.62    +14073
# 15  5.04  ...    +43157     +534     +794  +0.56  +0.56  +0.56    +43157
# 16  4.87  ...    +26715     +182     +443  +0.37  +0.37  +0.37    +26715
# 17  4.86  ...   --21913    --156    --644  +0.25  +0.25  +0.25   --21913
# 18  4.80  ...   --25421    --450    --586  +0.35  +0.35  +0.35   --25421
# 19  4.46  ...   --70460   --1053   --1495  +0.46  +0.46  +0.46   --70460
#
#      기관순매수    개인순매수 신용잔고율
# 0        0        0  0.00
# 1      +88   +11160  6.44
# 2    +2290  --16105  6.26
# 3    +1109    --414  6.21
# 4    --155    +2218  6.51
# 5    +1981   --3866  6.60
# 6    --390    --367  6.69
# 7      +25    +1768  5.61
# 8   --1316   --2255  5.46
# 9    +2068   --2080  5.11
# 10   --678    +3687  5.15
# 11      +8     +976  4.99
# 12    --13    +1300  4.92
# 13   +1046   --2132  4.90
# 14     +61     --65  4.99
# 15      +5    --804  5.04
# 16    --53    --459  4.87
# 17   --833    +1166  4.86
# 18   --194     +660  4.80
# 19   --736    +2120  4.46
#
# [20 rows x 22 columns]

# %%
import time
dfs = []
df = kiwoom.block_request("opt10086",
                          종목코드="161580",
                          기준일자="20250119",
                          표시구분=1,
                          output="일별주가요청",
                          next=1)

dfs.append(df)
a=0
while a<2:
    a = a+1
    df = kiwoom.block_request("opt10086",
                          종목코드="161580",
                          기준일자="20250119",
                          표시구분=1,
                          output="일별주가요청",
                          next=2)
    dfs.append(df)
    time.sleep(1)
    
df = pd.concat(dfs, ignore_index=True)
# Out:
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}

# %%
df.dtypes
# Out:
# 날짜        object
# 시가        object
# 고가        object
# 저가        object
# 종가        object
# 전일비       object
# 등락률       object
# 거래량       object
# 금액(백만)    object
# 신용비       object
# 개인        object
# 기관        object
# 외인수량      object
# 외국계       object
# 프로그램      object
# 외인비       object
# 외인보유      object
# 외인비중      object
# 외인순매수     object
# 기관순매수     object
# 개인순매수     object
# 신용잔고율     object
# dtype: object

# %%
df = df.drop(columns=["신용비", "개인", "기관", "외인수량", "외국계", "외인비", "외인보유", "외인비중", "신용잔고율"])

# %%
df.dtypes
# Out:
# 날짜        object
# 시가        object
# 고가        object
# 저가        object
# 종가        object
# 전일비       object
# 등락률       object
# 거래량       object
# 금액(백만)    object
# 프로그램      object
# 외인순매수     object
# 기관순매수     object
# 개인순매수     object
# dtype: object

# %%
df.head()
# Out:
#          날짜      시가      고가      저가      종가    전일비     등락률       거래량  금액(백만)  \
# 0  20250121  +30500  +31300  -30050  +31050   +650   +2.14   1517225   46522
# 1  20250120  -30700  +31800  -29800  -30400   -650   -2.09   3192857   98482
# 2  20250117  -26500  +33400  -26150  +31050  +4450  +16.73  16791418  515105
# 3  20250116  +27850  +28400  +26450  +26600   +750   +2.90   2782632   75902
# 4  20250115  -26000  +26950  -25350  -25850   -550   -2.08   2144086   56416
#
#       프로그램     외인순매수  기관순매수    개인순매수
# 0   --3367         0      0        0
# 1  --11785  --371717    +88   +11160
# 2   +16367   +653560  +2290  --16105
# 3     --77   --15172  +1109    --414
# 4   --2039   --60450  --155    +2218

# %%
columns_to_replace = ['프로그램','외인순매수','기관순매수','개인순매수']
df[columns_to_replace] = df[columns_to_replace].replace("--", "-", regex=True)
df.head()
# Out:
#          날짜      시가      고가      저가      종가    전일비     등락률       거래량  금액(백만)  \
# 0  20250121  +30500  +31300  -30050  +31050   +650   +2.14   1517225   46522
# 1  20250120  -30700  +31800  -29800  -30400   -650   -2.09   3192857   98482
# 2  20250117  -26500  +33400  -26150  +31050  +4450  +16.73  16791418  515105
# 3  20250116  +27850  +28400  +26450  +26600   +750   +2.90   2782632   75902
# 4  20250115  -26000  +26950  -25350  -25850   -550   -2.08   2144086   56416
#
#      프로그램    외인순매수  기관순매수   개인순매수
# 0   -3367        0      0       0
# 1  -11785  -371717    +88  +11160
# 2  +16367  +653560  +2290  -16105
# 3     -77   -15172  +1109    -414
# 4   -2039   -60450   -155   +2218

# %%
df.dtypes
# Out:
# 날짜        object
# 시가        object
# 고가        object
# 저가        object
# 종가        object
# 전일비       object
# 등락률       object
# 거래량        int32
# 금액(백만)    object
# 프로그램      object
# 외인순매수     object
# 기관순매수     object
# 개인순매수     object
# dtype: object

# %%
# Change the data type of '날짜' to datetime
df["날짜"] = pd.to_datetime(df["날짜"], format="%Y%m%d")

# Change the data type of '등락률' to float
df["등락률"] = df["등락률"].astype(float)

# Change all other columns to int
columns_to_convert = df.columns.difference(["날짜", "등락률"])
df[columns_to_convert] = df[columns_to_convert].astype(int)

# %%
# Divide the values in the "금액" column by 100
df["금액(백만)"] = df["금액(백만)"] / 100
# Rename the "금액" column to "금액(억)"
df.rename(columns={"금액(백만)": "금액(억)"}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\anaconda3\envs\py39_32\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File C:\anaconda3\envs\py39_32\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\anaconda3\envs\py39_32\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '금액(백만)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 12
#       9 df[columns_to_convert] = df[columns_to_convert].astype(int)
#      11 # Divide the values in the "금액" column by 100
# ---> 12 df["금액(백만)"] = df["금액(백만)"] / 100
#      13 # Rename the "금액" column to "금액(억)"
#      14 df.rename(columns={"금액(백만)": "금액(억)"}, inplace=True)
#
# File C:\anaconda3\envs\py39_32\lib\site-packages\pandas\core\frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File C:\anaconda3\envs\py39_32\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: '금액(백만)'

# %%
df.dtypes
# Out:
# 날짜       datetime64[ns]
# 시가                int32
# 고가                int32
# 저가                int32
# 종가                int32
# 전일비               int32
# 등락률             float64
# 거래량               int32
# 금액(억)             int32
# 프로그램              int32
# 외인순매수             int32
# 기관순매수             int32
# 개인순매수             int32
# dtype: object

# %%
df
# Out:
#            날짜     시가     고가     저가     종가   전일비    등락률       거래량  금액(억)  \
# 0  2025-01-21  30500  31300 -30050  31050   650   2.14   1517225    465
# 1  2025-01-20 -30700  31800 -29800 -30400  -650  -2.09   3192857    984
# 2  2025-01-17 -26500  33400 -26150  31050  4450  16.73  16791418   5151
# 3  2025-01-16  27850  28400  26450  26600   750   2.90   2782632    759
# 4  2025-01-15 -26000  26950 -25350 -25850  -550  -2.08   2144086    564
# 5  2025-01-14  25750  27400  25550  26400  2000   8.20   6674699   1767
# 6  2025-01-13 -24300  25650 -24150 -24400  -200  -0.81   1385678    344
# 7  2025-01-10  25950  26000 -24250 -24600  -100  -0.40   2298744    576
# 8  2025-01-09  24500  26800  24000  24700  1800   7.86  11911834   3043
# 9  2025-01-08 -20800  24050 -20800  22900  1650   7.76   4686085   1075
# 10 2025-01-07  23500  24600  21250  21250   400   1.92   4147588    956
# 11 2025-01-06  20650  21200 -20400  20850   400   1.96    908697    192
# 12 2025-01-03  20400  20700 -19890  20450   250   1.24    747986    151
# 13 2025-01-02  18440  20350 -18210  20200  1950  10.68    826122    161
# 14 2024-12-30 -18280  18400 -17970 -18250   -80  -0.44    271138     49
# 15 2024-12-27 -18560  19130 -17910 -18330  -400  -2.14    453142     83
# 16 2024-12-26  18730  19420 -18580  18730    30   0.16    555610    105
# 17 2024-12-24  20100  20400 -18640 -18700  -810  -4.15    850225    165
# 18 2024-12-23  19420  19890 -19090  19510   270   1.40    608978    118
# 19 2024-12-20  20350  21150 -19060 -19240  -910  -4.52   1609364    322
# 20 2024-12-19 -19980  20950 -19650 -20150  -450  -2.18   1743332    355
# 21 2024-12-18  18750  21300  18510  20600  2500  13.81   5049682   1018
# 22 2024-12-17  18050  18500  17600  18100   930   5.42   1224415    221
# 23 2024-12-16  17960  19000  16990  17170  1170   7.31   1504542    270
# 24 2024-12-13  15810  16470 -15500  16000   210   1.33    274051     43
# 25 2024-12-12  15520  15940 -15270  15790   430   2.80    215740     33
# 26 2024-12-11  14970  15440  14600  15360   850   5.86    199572     30
# 27 2024-12-10  13700  14600  13700  14510   810   5.91    245556     35
# 28 2024-12-09 -14410 -14500 -13600 -13700 -1260  -8.42    469525     65
# 29 2024-12-06  15780  16140 -14210 -14960  -450  -2.92    388654     58
# 30 2024-12-05  15570  15770 -15110  15410    90   0.59    172388     26
# 31 2024-12-04 -15450 -15890 -15020 -15320  -750  -4.67    283795     44
# 32 2024-12-03 -15810  16400 -15810  16070   120   0.75    226318     36
# 33 2024-12-02  16010  16350 -15780 -15950   -60  -0.37    209901     33
# 34 2024-11-29 -17100  17150 -16010 -16010 -1100  -6.43    388053     63
# 35 2024-11-28  16880  17500 -16700  17110   230   1.36    229306     39
# 36 2024-11-27  17430  17640 -16800 -16880  -390  -2.26    271869     46
# 37 2024-11-26  17500  17800 -17190 -17270  -140  -0.80    273017     47
# 38 2024-11-25  17100  17490  17070  17410   540   3.20    324438     56
# 39 2024-11-22  16950  18640  16730  16870   720   4.46   2317943    412
# 40 2024-11-21  16710  16720 -16100 -16150  -470  -2.83    229647     37
# 41 2024-11-20  16620  17120 -16360  16620    80   0.48    253027     42
# 42 2024-11-19  16600  17200 -16350 -16540   -60  -0.36    222751     37
# 43 2024-11-18  17490  17490 -16540 -16600  -750  -4.32    378201     64
# 44 2024-11-15 -15670  17750 -15650  17350  1450   9.12    716821    119
# 45 2024-11-14  16020  16410 -15690 -15900  -110  -0.69    450662     72
# 46 2024-11-13 -17000  17270 -16000 -16010 -1200  -6.97    627189    103
# 47 2024-11-12 -17810 -17850 -16920 -17210  -890  -4.92    612413    106
# 48 2024-11-11 -19090  19190 -17950 -18100 -1020  -5.33    539007     98
# 49 2024-11-08  19050  19950  19050  19120    90   0.47    384998     75
# 50 2024-11-07  19750  19750 -18810 -19030  -620  -3.16    425937     81
# 51 2024-11-06  21450  21450 -19290 -19650 -1300  -6.21    773126    155
# 52 2024-11-05  20950  20950 -20100  20950   250   1.21    383820     79
# 53 2024-11-04  20000  20900 -19480  20700   730   3.66    444228     89
# 54 2024-11-01 -20100  20700 -19850 -19970  -580  -2.82    424426     85
# 55 2024-10-31 -20300  21150 -20150 -20550  -150  -0.72    402995     83
# 56 2024-10-30  21300  21600 -20600 -20700  -450  -2.13    333332     70
# 57 2024-10-29  22000  22150 -20900 -21150  -650  -2.98    405362     86
# 58 2024-10-28 -20150  21800 -20150  21800  1300   6.34    609124    128
# 59 2024-10-25  21950  22500 -20500 -20500 -1350  -6.18    815790    173
#
#      프로그램   외인순매수  기관순매수  개인순매수
# 0   -3367       0      0      0
# 1  -11785 -371717     88  11160
# 2   16367  653560   2290 -16105
# 3     -77  -15172   1109   -414
# 4   -2039  -60450   -155   2218
# 5    1553   59559   1981  -3866
# 6    -168    8642   -390   -367
# 7   -2015  -90452     25   1768
# 8    2517  118497  -1316  -2255
# 9       7       0   2068  -2080
# 10  -2580  -88385   -678   3687
# 11   -920  -47770      8    976
# 12  -1262  -63911    -13   1300
# 13   1733   58790   1046  -2132
# 14    290   14073     61    -65
# 15    794   43157      5   -804
# 16    443   26715    -53   -459
# 17   -644  -21913   -833   1166
# 18   -586  -25421   -194    660
# 19  -1495  -70460   -736   2120
# 20  -2914 -139414  -1848   5137
# 21  -3577 -178880   2632   1165
# 22    -67   -2215   1258  -1108
# 23  -3376 -186170    967   2352
# 24   -154   -9868    -12    157
# 25   -232  -13989     31    188
# 26    357   23976    -21   -352
# 27   1326   91688      1  -1325
# 28   1713  123091   -974   -794
# 29   -220  -10649     18    161
# 30    340   22855    -24   -335
# 31    305   21493   -112   -159
# 32     78    8500   -136      2
# 33    711   45777     -6   -723
# 34  -1514  -92242   -172   1602
# 35    238   13771     22   -273
# 36   -730  -41570    -15    688
# 37   -572  -32683     -4    515
# 38   1010  118931    137  -1119
# 39  -3302 -193973    210   3054
# 40   -251  -14259    -10    247
# 41     27    1206    -30     15
# 42   -412  -24106    -31    388
# 43  -1843  -99437     -9   1820
# 44    160    9988   1055  -1273
# 45    587  -30212    -66   -648
# 46   2099  123767   -110  -1829
# 47   2433  137095     90  -2399
# 48   1416   78931    -29  -1424
# 49    836   42883     42   -838
# 50    -35    -943     95    -45
# 51  -3329 -162343   -159   3307
# 52   -439   -1751    -45    124
# 53    694   50341   -111   -938
# 54    904   46472    -86   -844
# 55   1153   56174    -28  -1112
# 56   -486  -20594     49    403
# 57  -1094  -51197     -2   1099
# 58   2381  136047   -166  -2236
# 59  -1240  -30137   -162   1366

# %%
df = df.iloc[::-1].reset_index(drop=True)
df
# Out:
#            날짜     시가     고가     저가     종가   전일비    등락률       거래량  금액(억)  \
# 0  2024-10-25  21950  22500 -20500 -20500 -1350  -6.18    815790    173
# 1  2024-10-28 -20150  21800 -20150  21800  1300   6.34    609124    128
# 2  2024-10-29  22000  22150 -20900 -21150  -650  -2.98    405362     86
# 3  2024-10-30  21300  21600 -20600 -20700  -450  -2.13    333332     70
# 4  2024-10-31 -20300  21150 -20150 -20550  -150  -0.72    402995     83
# 5  2024-11-01 -20100  20700 -19850 -19970  -580  -2.82    424426     85
# 6  2024-11-04  20000  20900 -19480  20700   730   3.66    444228     89
# 7  2024-11-05  20950  20950 -20100  20950   250   1.21    383820     79
# 8  2024-11-06  21450  21450 -19290 -19650 -1300  -6.21    773126    155
# 9  2024-11-07  19750  19750 -18810 -19030  -620  -3.16    425937     81
# 10 2024-11-08  19050  19950  19050  19120    90   0.47    384998     75
# 11 2024-11-11 -19090  19190 -17950 -18100 -1020  -5.33    539007     98
# 12 2024-11-12 -17810 -17850 -16920 -17210  -890  -4.92    612413    106
# 13 2024-11-13 -17000  17270 -16000 -16010 -1200  -6.97    627189    103
# 14 2024-11-14  16020  16410 -15690 -15900  -110  -0.69    450662     72
# 15 2024-11-15 -15670  17750 -15650  17350  1450   9.12    716821    119
# 16 2024-11-18  17490  17490 -16540 -16600  -750  -4.32    378201     64
# 17 2024-11-19  16600  17200 -16350 -16540   -60  -0.36    222751     37
# 18 2024-11-20  16620  17120 -16360  16620    80   0.48    253027     42
# 19 2024-11-21  16710  16720 -16100 -16150  -470  -2.83    229647     37
# 20 2024-11-22  16950  18640  16730  16870   720   4.46   2317943    412
# 21 2024-11-25  17100  17490  17070  17410   540   3.20    324438     56
# 22 2024-11-26  17500  17800 -17190 -17270  -140  -0.80    273017     47
# 23 2024-11-27  17430  17640 -16800 -16880  -390  -2.26    271869     46
# 24 2024-11-28  16880  17500 -16700  17110   230   1.36    229306     39
# 25 2024-11-29 -17100  17150 -16010 -16010 -1100  -6.43    388053     63
# 26 2024-12-02  16010  16350 -15780 -15950   -60  -0.37    209901     33
# 27 2024-12-03 -15810  16400 -15810  16070   120   0.75    226318     36
# 28 2024-12-04 -15450 -15890 -15020 -15320  -750  -4.67    283795     44
# 29 2024-12-05  15570  15770 -15110  15410    90   0.59    172388     26
# 30 2024-12-06  15780  16140 -14210 -14960  -450  -2.92    388654     58
# 31 2024-12-09 -14410 -14500 -13600 -13700 -1260  -8.42    469525     65
# 32 2024-12-10  13700  14600  13700  14510   810   5.91    245556     35
# 33 2024-12-11  14970  15440  14600  15360   850   5.86    199572     30
# 34 2024-12-12  15520  15940 -15270  15790   430   2.80    215740     33
# 35 2024-12-13  15810  16470 -15500  16000   210   1.33    274051     43
# 36 2024-12-16  17960  19000  16990  17170  1170   7.31   1504542    270
# 37 2024-12-17  18050  18500  17600  18100   930   5.42   1224415    221
# 38 2024-12-18  18750  21300  18510  20600  2500  13.81   5049682   1018
# 39 2024-12-19 -19980  20950 -19650 -20150  -450  -2.18   1743332    355
# 40 2024-12-20  20350  21150 -19060 -19240  -910  -4.52   1609364    322
# 41 2024-12-23  19420  19890 -19090  19510   270   1.40    608978    118
# 42 2024-12-24  20100  20400 -18640 -18700  -810  -4.15    850225    165
# 43 2024-12-26  18730  19420 -18580  18730    30   0.16    555610    105
# 44 2024-12-27 -18560  19130 -17910 -18330  -400  -2.14    453142     83
# 45 2024-12-30 -18280  18400 -17970 -18250   -80  -0.44    271138     49
# 46 2025-01-02  18440  20350 -18210  20200  1950  10.68    826122    161
# 47 2025-01-03  20400  20700 -19890  20450   250   1.24    747986    151
# 48 2025-01-06  20650  21200 -20400  20850   400   1.96    908697    192
# 49 2025-01-07  23500  24600  21250  21250   400   1.92   4147588    956
# 50 2025-01-08 -20800  24050 -20800  22900  1650   7.76   4686085   1075
# 51 2025-01-09  24500  26800  24000  24700  1800   7.86  11911834   3043
# 52 2025-01-10  25950  26000 -24250 -24600  -100  -0.40   2298744    576
# 53 2025-01-13 -24300  25650 -24150 -24400  -200  -0.81   1385678    344
# 54 2025-01-14  25750  27400  25550  26400  2000   8.20   6674699   1767
# 55 2025-01-15 -26000  26950 -25350 -25850  -550  -2.08   2144086    564
# 56 2025-01-16  27850  28400  26450  26600   750   2.90   2782632    759
# 57 2025-01-17 -26500  33400 -26150  31050  4450  16.73  16791418   5151
# 58 2025-01-20 -30700  31800 -29800 -30400  -650  -2.09   3192857    984
# 59 2025-01-21  30500  31300 -30050  31050   650   2.14   1517225    465
#
#      프로그램   외인순매수  기관순매수  개인순매수
# 0   -1240  -30137   -162   1366
# 1    2381  136047   -166  -2236
# 2   -1094  -51197     -2   1099
# 3    -486  -20594     49    403
# 4    1153   56174    -28  -1112
# 5     904   46472    -86   -844
# 6     694   50341   -111   -938
# 7    -439   -1751    -45    124
# 8   -3329 -162343   -159   3307
# 9     -35    -943     95    -45
# 10    836   42883     42   -838
# 11   1416   78931    -29  -1424
# 12   2433  137095     90  -2399
# 13   2099  123767   -110  -1829
# 14    587  -30212    -66   -648
# 15    160    9988   1055  -1273
# 16  -1843  -99437     -9   1820
# 17   -412  -24106    -31    388
# 18     27    1206    -30     15
# 19   -251  -14259    -10    247
# 20  -3302 -193973    210   3054
# 21   1010  118931    137  -1119
# 22   -572  -32683     -4    515
# 23   -730  -41570    -15    688
# 24    238   13771     22   -273
# 25  -1514  -92242   -172   1602
# 26    711   45777     -6   -723
# 27     78    8500   -136      2
# 28    305   21493   -112   -159
# 29    340   22855    -24   -335
# 30   -220  -10649     18    161
# 31   1713  123091   -974   -794
# 32   1326   91688      1  -1325
# 33    357   23976    -21   -352
# 34   -232  -13989     31    188
# 35   -154   -9868    -12    157
# 36  -3376 -186170    967   2352
# 37    -67   -2215   1258  -1108
# 38  -3577 -178880   2632   1165
# 39  -2914 -139414  -1848   5137
# 40  -1495  -70460   -736   2120
# 41   -586  -25421   -194    660
# 42   -644  -21913   -833   1166
# 43    443   26715    -53   -459
# 44    794   43157      5   -804
# 45    290   14073     61    -65
# 46   1733   58790   1046  -2132
# 47  -1262  -63911    -13   1300
# 48   -920  -47770      8    976
# 49  -2580  -88385   -678   3687
# 50      7       0   2068  -2080
# 51   2517  118497  -1316  -2255
# 52  -2015  -90452     25   1768
# 53   -168    8642   -390   -367
# 54   1553   59559   1981  -3866
# 55  -2039  -60450   -155   2218
# 56    -77  -15172   1109   -414
# 57  16367  653560   2290 -16105
# 58 -11785 -371717     88  11160
# 59  -3367       0      0      0

# %% [markdown]
# ### mplfinance library

# %%
df.dtypes
# Out:
# 날짜       datetime64[ns]
# 시가                int32
# 고가                int32
# 저가                int32
# 종가                int32
# 전일비               int32
# 등락률             float64
# 거래량               int32
# 금액(억)             int32
# 프로그램              int32
# 외인순매수             int32
# 기관순매수             int32
# 개인순매수             int32
# dtype: object

# %%
# Rename columns
df = df.rename(columns={
    "날짜": "datetime",
    "시가": "Open",
    "고가": "High",
    "저가": "Low",
    "종가": "Close",
    "거래량": "Volume",       # Optional if volume is available
    "전일비": "Change",       # Change compared to the previous day
    "등락률": "ChangeRate",   # Change rate (percentage)
    "금액(억)": "TradingValue", # Trading value
    "프로그램": "Program",    # Program trading
    "외인순매수": "ForeignNetBuy", # Foreign net buy
    "기관순매수": "InstitutionNetBuy", # Institution net buy
    "개인순매수": "IndividualNetBuy"  # Individual net buy
})

# Check the DataFrame to ensure the columns are renamed correctly

# %%
df.head()
# Out:
#     datetime   Open   High    Low  Close  Change  ChangeRate  Volume  \
# 0 2024-10-25  21950  22500 -20500 -20500   -1350       -6.18  815790
# 1 2024-10-28 -20150  21800 -20150  21800    1300        6.34  609124
# 2 2024-10-29  22000  22150 -20900 -21150    -650       -2.98  405362
# 3 2024-10-30  21300  21600 -20600 -20700    -450       -2.13  333332
# 4 2024-10-31 -20300  21150 -20150 -20550    -150       -0.72  402995
#
#    TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  IndividualNetBuy
# 0           173    -1240         -30137               -162              1366
# 1           128     2381         136047               -166             -2236
# 2            86    -1094         -51197                 -2              1099
# 3            70     -486         -20594                 49               403
# 4            83     1153          56174                -28             -1112

# %%
# DataFrame의 인덱스를 날짜로 설정 (mplfinance가 요구하는 포맷)
df.set_index("datetime", inplace=True)

# %%
df.head()
# Out:
#              Open   High    Low  Close  Change  ChangeRate  Volume  \
# datetime
# 2024-10-25  21950  22500 -20500 -20500   -1350       -6.18  815790
# 2024-10-28 -20150  21800 -20150  21800    1300        6.34  609124
# 2024-10-29  22000  22150 -20900 -21150    -650       -2.98  405362
# 2024-10-30  21300  21600 -20600 -20700    -450       -2.13  333332
# 2024-10-31 -20300  21150 -20150 -20550    -150       -0.72  402995
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 2024-10-25           173    -1240         -30137               -162
# 2024-10-28           128     2381         136047               -166
# 2024-10-29            86    -1094         -51197                 -2
# 2024-10-30            70     -486         -20594                 49
# 2024-10-31            83     1153          56174                -28
#
#             IndividualNetBuy
# datetime
# 2024-10-25              1366
# 2024-10-28             -2236
# 2024-10-29              1099
# 2024-10-30               403
# 2024-10-31             -1112

# %%
# Apply absolute value transformation to specific columns
columns_to_transform = ["Open", "High", "Low", "Close"]
df[columns_to_transform] = df[columns_to_transform].abs()

# %%
df.head()
# Out:
#              Open   High    Low  Close  Change  ChangeRate  Volume  \
# datetime
# 2024-10-25  21950  22500  20500  20500   -1350       -6.18  815790
# 2024-10-28  20150  21800  20150  21800    1300        6.34  609124
# 2024-10-29  22000  22150  20900  21150    -650       -2.98  405362
# 2024-10-30  21300  21600  20600  20700    -450       -2.13  333332
# 2024-10-31  20300  21150  20150  20550    -150       -0.72  402995
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 2024-10-25           173    -1240         -30137               -162
# 2024-10-28           128     2381         136047               -166
# 2024-10-29            86    -1094         -51197                 -2
# 2024-10-30            70     -486         -20594                 49
# 2024-10-31            83     1153          56174                -28
#
#             IndividualNetBuy
# datetime
# 2024-10-25              1366
# 2024-10-28             -2236
# 2024-10-29              1099
# 2024-10-30               403
# 2024-10-31             -1112

# %%
# 2. 봉차트 그리기
mpf.plot(
    df,
    type="candle",  # 봉차트
    style="charles",  # 스타일 (다양한 스타일 지원)
    title="Stock Name",  # 차트 제목
    ylabel="Price",  # y축 라벨
    volume=False  # 거래량 표시 여부 (False로 설정)
)

# %%
# Custom market colors
custom_colors = mpf.make_marketcolors(
    up="red",    # Custom color for up (e.g., blue)
    down="blue", # Custom color for down (e.g., orange)
    wick="black",  # Wick color
    edge="black"   # Edge color
)

# Custom style with the market colors
custom_style = mpf.make_mpf_style(
    marketcolors=custom_colors, 
    gridcolor="gray",  # Gridline color
    gridstyle="--"     # Gridline style
)


mpf.plot(
    df,
    type="candle",
    style=custom_style,
    title="Name",
    ylabel="Price",
    volume=True  
)

# %%
df.head()
# Out:
#              Open   High    Low  Close    전일비     등락률    Volume  금액(백만)   신용비  \
# 날짜
# 2025-01-21  30500  31000  30050  30300   -100   -0.33    713999   21824  0.00
# 2025-01-20  30700  31800  29800  30400   -650   -2.09   3192857   98482  6.44
# 2025-01-17  26500  33400  26150  31050  +4450  +16.73  16791418  515105  6.26
# 2025-01-16  27850  28400  26450  26600   +750   +2.90   2782632   75902  6.21
# 2025-01-15  26000  26950  25350  25850   -550   -2.08   2144086   56416  6.51
#
#                  개인  ...      외인수량      외국계     프로그램    외인비   외인보유   외인비중  \
# 날짜                   ...
# 2025-01-21        0  ...         0   --1682   --2102  +1.32  +1.32  +1.32
# 2025-01-20   +11160  ...  --371717  --11048  --11785  +1.32  +1.32  +1.32
# 2025-01-17  --16105  ...   +653560   +19307   +16367  +2.95  +2.95  +2.95
# 2025-01-16    --414  ...   --15172    --309     --77  +0.09  +0.09  +0.09
# 2025-01-15    +2218  ...   --60450      +40   --2039  +0.16  +0.16  +0.16
#
#                외인순매수  기관순매수    개인순매수 신용잔고율
# 날짜
# 2025-01-21         0      0        0  0.00
# 2025-01-20  --371717    +88   +11160  6.44
# 2025-01-17   +653560  +2290  --16105  6.26
# 2025-01-16   --15172  +1109    --414  6.21
# 2025-01-15   --60450  --155    +2218  6.51
#
# [5 rows x 21 columns]

# %%
df['10DMA']=df['Close'].rolling(window=10).mean()
df['20DMA']=df['Close'].rolling(window=20).mean()
df['10DMA']
# Out:
# datetime
# 2024-10-25        NaN
# 2024-10-28        NaN
# 2024-10-29        NaN
# 2024-10-30        NaN
# 2024-10-31        NaN
# 2024-11-01        NaN
# 2024-11-04        NaN
# 2024-11-05        NaN
# 2024-11-06        NaN
# 2024-11-07    20500.0
# 2024-11-08    20362.0
# 2024-11-11    19992.0
# 2024-11-12    19598.0
# 2024-11-13    19129.0
# 2024-11-14    18664.0
# 2024-11-15    18402.0
# 2024-11-18    17992.0
# 2024-11-19    17551.0
# 2024-11-20    17248.0
# 2024-11-21    16960.0
# 2024-11-22    16735.0
# 2024-11-25    16666.0
# 2024-11-26    16672.0
# 2024-11-27    16759.0
# 2024-11-28    16880.0
# 2024-11-29    16746.0
# 2024-12-02    16681.0
# 2024-12-03    16634.0
# 2024-12-04    16504.0
# 2024-12-05    16430.0
# 2024-12-06    16239.0
# 2024-12-09    15868.0
# 2024-12-10    15592.0
# 2024-12-11    15440.0
# 2024-12-12    15308.0
# 2024-12-13    15307.0
# 2024-12-16    15429.0
# 2024-12-17    15632.0
# 2024-12-18    16160.0
# 2024-12-19    16634.0
# 2024-12-20    17062.0
# 2024-12-23    17643.0
# 2024-12-24    18062.0
# 2024-12-26    18399.0
# 2024-12-27    18653.0
# 2024-12-30    18878.0
# 2025-01-02    19181.0
# 2025-01-03    19416.0
# 2025-01-06    19441.0
# 2025-01-07    19551.0
# 2025-01-08    19917.0
# 2025-01-09    20436.0
# 2025-01-10    21026.0
# 2025-01-13    21593.0
# 2025-01-14    22400.0
# 2025-01-15    23160.0
# 2025-01-16    23800.0
# 2025-01-17    24860.0
# 2025-01-20    25815.0
# 2025-01-21    26795.0
# Name: 10DMA, dtype: float64

# %%
# Custom market colors
custom_colors = mpf.make_marketcolors(
    up="red",    # Custom color for up (e.g., blue)
    down="blue", # Custom color for down (e.g., orange)
    wick="black",  # Wick color
    edge="black"   # Edge color
)

# Custom style with the market colors
custom_style = mpf.make_mpf_style(
    marketcolors=custom_colors, 
    gridcolor="gray",  # Gridline color
    gridstyle="--"     # Gridline style
)

# Define the additional plots for the moving averages
add_plots = [
    mpf.make_addplot(df["10DMA"], color="navy", width=1.0, linestyle="solid"),
    mpf.make_addplot(df["20DMA"], color="gold", width=2.0, linestyle="solid")
]


mpf.plot(
    df,
    type="candle",
    style=custom_style,
    title="Name",
    ylabel="Price",
    volume=True,
    addplot=add_plots
)
