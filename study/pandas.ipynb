# %% [markdown]
# ## Series

# %%
import pandas as pd
s = pd.Series([1,2,3,6,7])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    6
# 4    7
# dtype: int64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s[1]
# Out:
# 2

# %%
s = pd.Series([1,2,3,6,7], 
              index=['a','b','c','d','e'])
s
# Out:
# a    1
# b    2
# c    3
# d    6
# e    7
# dtype: int64

# %%
s['c']
# Out:
# 3

# %%
s[['c','d','e']]
# Out:
# c    3
# d    6
# e    7
# dtype: int64

# %%
'b' in s
# Out:
# True

# %%
s[2:]
# Out:
# c    3
# d    6
# e    7
# dtype: int64

# %%
s.unique()
# Out:
# array([1, 2, 3, 6, 7], dtype=int64)

# %%
s.value_counts()
# Out:
# 1    1
# 2    1
# 3    1
# 6    1
# 7    1
# dtype: int64

# %%
s.isin([2,3])
# Out:
# a    False
# b     True
# c     True
# d    False
# e    False
# dtype: bool

# %%
t = {'서울':9720846,
     '부산':3404423,
     '인천':2947217}
t
# Out:
# {'서울': 9720846, '부산': 3404423, '인천': 2947217}

# %%
t_series = pd.Series(t)
t_series
# Out:
# 서울    9720846
# 부산    3404423
# 인천    2947217
# dtype: int64

# %% [markdown]
# ### Series indexing

# %%
s = pd.Series(['a','b','c','d','e'], index=[1,3,5,7,9])
s
# Out:
# 1    a
# 3    b
# 5    c
# 7    d
# 9    e
# dtype: object

# %%
s[3] # looking for index 1
# Out:
# 'b'

# %%
s[1:5]
# Out:
# 3    b
# 5    c
# 7    d
# 9    e
# dtype: object

# %%
s.iloc[0] # looking for 0st index
# Out:
# 'a'

# %%
s.iloc[2:4]
# Out:
# 5    c
# 7    d
# dtype: object

# %% [markdown]
# ## DataFrame
# - A DataFrame sends a 2D list as a parameter
# - A DataFrame consists of columns, an index, and values

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "Salary": [50000.0, 60000.0, 70000.0],
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age   Salary
# 0    Alice   25  50000.0
# 1      Bob   30  60000.0
# 2  Charlie   35  70000.0

# %% [markdown]
# #### dtypes
# - check data types

# %%
df.dtypes
# Out:
# Name       object
# Age         int64
# Salary    float64
# dtype: object

# %% [markdown]
# #### astype()
# - change data type

# %%
df["Age"] = df["Age"].astype("float64")

# %%
df.dtypes
# Out:
# Name       object
# Age       float64
# Salary    float64
# dtype: object

# %% [markdown]
# #### replace()
# - The replace method is used to replace values in a DataFrame or Series
# - Setting regex=True treats the pattern as a regular expression.

# %%
import pandas as pd

# Example DataFrame
data = {
    "a": ["--10", "20", "--30"],
    "b": ["--5", "15", "--25"],
    "c": ["--8", "--18", "28"],
    "d": ["0", "--1", "--2"],
    "e": ["Unchanged", "Value", "--50"]  # Column not to be modified
}
df = pd.DataFrame(data)

# Replace "--" with "-" in specific columns
columns_to_replace = ["a", "b", "c", "d"]
df[columns_to_replace] = df[columns_to_replace].replace("--", "-", regex=True)

print(df)
# Out:
#      a    b    c   d          e
# 0  -10   -5   -8   0  Unchanged
# 1   20   15  -18  -1      Value
# 2  -30  -25   28  -2       --50

# %% [markdown]
# ## Creation of DataFrame
# - Using list, Series, dict, ndarrays

# %% [markdown]
# ### DataFrame creation using list

# %%
data = [
    ['1000', 'Steve', 90.72], 
    ['1001', 'James', 78.09], 
    ['1002', 'Doyeon', 98.43], 
    ['1003', 'Jane', 64.19], 
    ['1004', 'Pilwoong', 81.30],
    ['1005', 'Tony', 99.14],
]

df = pd.DataFrame(data)
print(df)
# Out:
#       0         1      2
# 0  1000     Steve  90.72
# 1  1001     James  78.09
# 2  1002    Doyeon  98.43
# 3  1003      Jane  64.19
# 4  1004  Pilwoong  81.30
# 5  1005      Tony  99.14

# %%
import pandas as pd

values = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
w = ['A', 'B', 'C']
l = ['one', 'two', 'three']


df = pd.DataFrame(values, index=l, columns=w)

print(df)
# Out:
#        A  B  C
# one    1  2  3
# two    4  5  6
# three  7  8  9

# %% [markdown]
# ###  DataFrame creation using dict

# %%
data = {
    'ID' : ['1000', '1001', '1002', '1003', '1004', '1005'],
    'Name' : [ 'Steve', 'James', 'Doyeon', 'Jane', 'Pilwoong', 'Tony'],
    'Score': [90.72, 78.09, 98.43, 64.19, 81.30, 99.14]
    }

df = pd.DataFrame(data)
print(df)
# Out:
#      ID      Name  Score
# 0  1000     Steve  90.72
# 1  1001     James  78.09
# 2  1002    Doyeon  98.43
# 3  1003      Jane  64.19
# 4  1004  Pilwoong  81.30
# 5  1005      Tony  99.14

# %%
pd.DataFrame([{'A':1,'B':2,'C':3}, {'A':4,'B':5,'D':6}])
# Out:
#    A  B    C    D
# 0  1  2  3.0  NaN
# 1  4  5  NaN  6.0

# %% [markdown]
# #### iterrows()

# %%
import pandas as pd
data = {'col1':[1,2],'col2':[3,4]}
idx = ['row1','row2']
df = pd.DataFrame(data = data, index=idx)
print(df)
# Out:
#       col1  col2
# row1     1     3
# row2     2     4

# %%
df2 = df.iterrows()
type(df2)
# Out:
# generator

# %%
next(df2)
# Out:
# ('row1',
#  col1    1
#  col2    3
#  Name: row1, dtype: int64)

# %%
next(df2)
# Out:
# ('row2',
#  col1    2
#  col2    4
#  Name: row2, dtype: int64)

# %% [markdown]
# ### Update Columns, index

# %%
df.columns = ['ID','Name','Score']
print(df)
# Out:
#      ID      Name  Score
# 0  1000     Steve  90.72
# 1  1001     James  78.09
# 2  1002    Doyeon  98.43
# 3  1003      Jane  64.19
# 4  1004  Pilwoong  81.30
# 5  1005      Tony  99.14

# %%
df.index = ['1st','2nd','3rd','4th','5th','6th']
df
# Out:
#        ID      Name  Score
# 1st  1000     Steve  90.72
# 2nd  1001     James  78.09
# 3rd  1002    Doyeon  98.43
# 4th  1003      Jane  64.19
# 5th  1004  Pilwoong  81.30
# 6th  1005      Tony  99.14

# %% [markdown]
# #### concat()
# - If you have multiple DataFrames stored in a list, you can combine them into a single DataFrame using pd.concat.
# - By default, pd.concat combines DataFrames vertically (row-wise).

# %%
import pandas as pd

# Create two DataFrames
df1 = pd.DataFrame({"A": [1, 2], "B": [3, 4]})
df2 = pd.DataFrame({"A": [5, 6], "B": [7, 8]})

# Create an empty list
dataframes = []

# Append DataFrames to the list
dataframes.append(df1)
dataframes.append(df2)

print(dataframes)
print('-------------')
# Combine DataFrames in the list into a single DataFrame
df_combined = pd.concat(dataframes)
print(df_combined)
# Out:
# [   A  B
# 0  1  3
# 1  2  4,    A  B
# 0  5  7
# 1  6  8]
# -------------
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %% [markdown]
# ## Reading of DataFrame
# - df.head(n)
# - df.tail(n)
# - df['column name']

# %%
import sys
sys.path.append('C:\workspace\SystemTrading') 
sys.path
# Out:
# ['C:\\anaconda3\\envs\\py39_32\\python39.zip',
#  'C:\\anaconda3\\envs\\py39_32\\DLLs',
#  'C:\\anaconda3\\envs\\py39_32\\lib',
#  'C:\\anaconda3\\envs\\py39_32',
#  '',
#  'C:\\anaconda3\\envs\\py39_32\\lib\\site-packages',
#  'C:\\anaconda3\\envs\\py39_32\\lib\\site-packages\\locket-0.2.1-py3.9.egg',
#  'C:\\anaconda3\\envs\\py39_32\\lib\\site-packages\\win32',
#  'C:\\anaconda3\\envs\\py39_32\\lib\\site-packages\\win32\\lib',
#  'C:\\anaconda3\\envs\\py39_32\\lib\\site-packages\\Pythonwin',
#  'C:\\workspace\\SystemTrading']

# %%
import pandas as pd
import DayChart

# %%
from pykiwoom.kiwoom import *
kiwoom = Kiwoom()
kiwoom.CommConnect(block=True)
print("블록킹 로그인 완료")
# Out:
# 블록킹 로그인 완료

# %%
sss = DayChart.StockDataProcessor(kiwoom)

df = sss.get_stock_data('현대힘스','20250123')

df = sss.preprocess_data(df)
# Out:
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}

# %%
df.head(3) # defualt = 5

# %%
df.tail(3)
# Out:
#           날짜      시가      고가      저가      종가    전일비     등락률      거래량  금액(백만)  \
# 17  20241220  +20350  +21150  -19060  -19240   -910   -4.52  1609364   32281
# 18  20241219  -19980  +20950  -19650  -20150   -450   -2.18  1743332   35546
# 19  20241218  +18750  +21300  +18510  +20600  +2500  +13.81  5049682  101896
#
#      신용비  ...      외인수량     외국계    프로그램    외인비   외인보유   외인비중     외인순매수  \
# 17  4.46  ...   --70460  --1053  --1495  +0.46  +0.46  +0.46   --70460
# 18  4.04  ...  --139414  --2904  --2914  +0.77  +0.77  +0.77  --139414
# 19  4.12  ...  --178880  --2577  --3577  +1.38  +1.38  +1.38  --178880
#
#      기관순매수  개인순매수 신용잔고율
# 17   --736  +2120  4.46
# 18  --1848  +5137  4.04
# 19   +2632  +1165  4.12
#
# [3 rows x 22 columns]

# %%
df.sample(3)
# Out:
#              Open   High    Low  Close  Changes  ChangeRate   Volume  \
# datetime
# 2025-01-07  13850  14980  13760  14410      750        5.49  1872613
# 2025-01-24  20100  20150  19210  19630       50        0.26  1080092
# 2024-12-17  12860  12930  12650  12660     -200       -1.56   156861
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 2025-01-07        271.00     -216         -14278                  0
# 2025-01-24        211.75    -1221         -61342                  7
# 2024-12-17         20.06     -152         -10468                -15
#
#             IndividualNetBuy
# datetime
# 2025-01-07               338
# 2025-01-24              1430
# 2024-12-17               111

# %% [markdown]
# ### DataFrame indexing

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Changes', 'ChangeRate', 'Volume',
#        'TradingValue', 'Program', 'ForeignNetBuy', 'InstitutionNetBuy',
#        'IndividualNetBuy'],
#       dtype='object')

# %%
df['Open'].head(3)
# Out:
# datetime
# 2024-11-27    15040
# 2024-11-28    14310
# 2024-11-29    14630
# Name: Open, dtype: int32

# %%
df.Open.head()
# Out:
# datetime
# 2024-11-27    15040
# 2024-11-28    14310
# 2024-11-29    14630
# 2024-12-02    14370
# 2024-12-03    13210
# Name: Open, dtype: int32

# %%
type(df['Open'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#              Open   High    Low  Close  Changes  ChangeRate    Volume  \
# datetime
# 2024-11-27  15040  15500  14330  14440     -750       -4.94    678688
# 2024-11-28  14310  15890  14140  14630      190        1.32   2332620
# 2024-11-29  14630  14840  14220  14310     -320       -2.19    343664
# 2024-12-02  14370  14640  13260  13330     -980       -6.85    499515
# 2024-12-03  13210  13810  13200  13710      380        2.85    309442
# 2024-12-04  13170  13480  12780  13000     -710       -5.18    516062
# 2024-12-05  12900  13040  12360  12670     -330       -2.54    271911
# 2024-12-06  12590  12640  11560  12160     -510       -4.03    415372
# 2024-12-09  11770  11880  11000  11050    -1110       -9.13    363192
# 2024-12-10  11190  12210  11190  12080     1030        9.32    326692
# 2024-12-11  12080  12550  11750  12540      460        3.81    264062
# 2024-12-12  12610  12640  12120  12420     -120       -0.96    198214
# 2024-12-13  12420  12850  12170  12800      380        3.06    214218
# 2024-12-16  12820  12950  12590  12860       60        0.47    182519
# 2024-12-17  12860  12930  12650  12660     -200       -1.56    156861
# 2024-12-18  12600  13170  12520  12700       40        0.32    241524
# 2024-12-19  12320  13190  12260  13060      360        2.83    366688
# 2024-12-20  13180  14920  12840  13460      400        3.06   3596835
# 2024-12-23  13930  14200  13610  13690      230        1.71    774745
# 2024-12-24  13760  13940  13360  13630      -60       -0.44    292295
# 2024-12-26  14050  14660  13700  13980      350        2.57   1164584
# 2024-12-27  14080  14080  13220  13430     -550       -3.93    413371
# 2024-12-30  13490  13570  13250  13430        0        0.00    169989
# 2025-01-02  13300  13820  12880  13700      270        2.01    298710
# 2025-01-03  13720  13920  13500  13560     -140       -1.02    237531
# 2025-01-06  13460  13670  13370  13660      100        0.74    170214
# 2025-01-07  13850  14980  13760  14410      750        5.49   1872613
# 2025-01-08  14630  14640  14220  14520      110        0.76    631843
# 2025-01-09  14700  14700  14150  14520        0        0.00    328253
# 2025-01-10  14560  18450  14420  17800     3280       22.59  21280011
# 2025-01-13  18020  18020  16960  16960     -840       -4.72   2785962
# 2025-01-14  16940  20250  16850  18490     1530        9.02  17955440
# 2025-01-15  18670  19430  18400  18490        0        0.00   3884488
# 2025-01-16  18860  18900  18200  18900      410        2.22   1255764
# 2025-01-17  18660  19300  18510  18810      -90       -0.48   2034230
# 2025-01-20  20650  22350  19820  20100     1290        6.86   7974403
# 2025-01-21  20150  21300  19960  20650      550        2.74   2750952
# 2025-01-22  20750  20850  20000  20150     -500       -2.42   1196511
# 2025-01-23  20150  20250  19380  19580     -570       -2.83   1068864
# 2025-01-24  20100  20150  19210  19630       50        0.26   1080092
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 2024-11-27        101.88     -524         -34227                -31
# 2024-11-28        356.37      343          19242                  1
# 2024-11-29         49.47     -376         -25924                 -1
# 2024-12-02         68.63       61          -1931                  2
# 2024-12-03         41.92      749          55426                  0
# 2024-12-04         67.29      620          47933                 -1
# 2024-12-05         34.34      803          63689                  0
# 2024-12-06         49.92      509          43160                  0
# 2024-12-09         41.16      676          60035                  4
# 2024-12-10         38.72      414          35380                 -7
# 2024-12-11         32.73      -25          -1879                  0
# 2024-12-12         24.47     -315         -25339                  1
# 2024-12-13         26.78     -101          -8247                  9
# 2024-12-16         23.25     -191         -14968                 -1
# 2024-12-17         20.06     -152         -10468                -15
# 2024-12-18         30.98     -214         -15674                -15
# 2024-12-19         47.23      186          14156                144
# 2024-12-20        506.70    -2025        -145061                397
# 2024-12-23        107.55     -521         -36445               -164
# 2024-12-24         39.64      342          25676                -50
# 2024-12-26        164.54     -705         -49827                  4
# 2024-12-27         56.19     -126          -8745                 -1
# 2024-12-30         22.77      372          27835                  4
# 2025-01-02         40.43      461          34165                  6
# 2025-01-03         32.34     -576         -42198                  1
# 2025-01-06         23.06      224          16591                  0
# 2025-01-07        271.00     -216         -14278                  0
# 2025-01-08         91.21     -330         -22450                  0
# 2025-01-09         47.29       21           1536                  1
# 2025-01-10       3706.61     2070         120867                 -1
# 2025-01-13        484.40    -2280        -126328                 -6
# 2025-01-14       3417.44     1893         109466                 13
# 2025-01-15        734.62    -2126        -105437                -20
# 2025-01-16        233.10     -145          -6900                 13
# 2025-01-17        389.74      131           7424                 79
# 2025-01-20       1684.08      386          24751                -65
# 2025-01-21        567.68      503          26086                -15
# 2025-01-22        243.84     -492         -24295                 -4
# 2025-01-23        210.13     1797          91996                 67
# 2025-01-24        211.75    -1221         -61342                  7
#
#             IndividualNetBuy
# datetime
# 2024-11-27               548
# 2024-11-28              -271
# 2024-11-29               311
# 2024-12-02                 8
# 2024-12-03              -782
# 2024-12-04              -771
# 2024-12-05              -820
# 2024-12-06              -554
# 2024-12-09              -623
# 2024-12-10              -370
# 2024-12-11                24
# 2024-12-12               326
# 2024-12-13               104
# 2024-12-16               185
# 2024-12-17               111
# 2024-12-18               328
# 2024-12-19              -317
# 2024-12-20              1643
# 2024-12-23               681
# 2024-12-24              -304
# 2024-12-26               777
# 2024-12-27               138
# 2024-12-30              -378
# 2025-01-02              -503
# 2025-01-03               560
# 2025-01-06              -226
# 2025-01-07               338
# 2025-01-08               292
# 2025-01-09               -12
# 2025-01-10             -1995
# 2025-01-13              2276
# 2025-01-14             -1750
# 2025-01-15              1725
# 2025-01-16               153
# 2025-01-17                -9
# 2025-01-20              -205
# 2025-01-21              -514
# 2025-01-22               507
# 2025-01-23             -1885
# 2025-01-24              1430

# %%
df.index
# Out:
# DatetimeIndex(['2024-11-27', '2024-11-28', '2024-11-29', '2024-12-02',
#                '2024-12-03', '2024-12-04', '2024-12-05', '2024-12-06',
#                '2024-12-09', '2024-12-10', '2024-12-11', '2024-12-12',
#                '2024-12-13', '2024-12-16', '2024-12-17', '2024-12-18',
#                '2024-12-19', '2024-12-20', '2024-12-23', '2024-12-24',
#                '2024-12-26', '2024-12-27', '2024-12-30', '2025-01-02',
#                '2025-01-03', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10', '2025-01-13', '2025-01-14',
#                '2025-01-15', '2025-01-16', '2025-01-17', '2025-01-20',
#                '2025-01-21', '2025-01-22', '2025-01-23', '2025-01-24'],
#               dtype='datetime64[ns]', name='datetime', freq=None)

# %% [markdown]
# #### .loc vs .iloc

# %% [markdown]
# - If the index is a DatetimeIndex, .loc expects datetime-like values (e.g., strings or datetime objects) as labels, not integers
# - If you want to slice based on row positions (integers like 3), use .iloc

# %%
df.loc["2024-11-27":"2024-12-01"]
# Out:
#              Open   High    Low  Close  Changes  ChangeRate   Volume  \
# datetime
# 2024-11-27  15040  15500  14330  14440     -750       -4.94   678688
# 2024-11-28  14310  15890  14140  14630      190        1.32  2332620
# 2024-11-29  14630  14840  14220  14310     -320       -2.19   343664
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 2024-11-27        101.88     -524         -34227                -31
# 2024-11-28        356.37      343          19242                  1
# 2024-11-29         49.47     -376         -25924                 -1
#
#             IndividualNetBuy
# datetime
# 2024-11-27               548
# 2024-11-28              -271
# 2024-11-29               311

# %%
df.iloc[:3]
# Out:
#              Open   High    Low  Close  Changes  ChangeRate   Volume  \
# datetime
# 2024-11-27  15040  15500  14330  14440     -750       -4.94   678688
# 2024-11-28  14310  15890  14140  14630      190        1.32  2332620
# 2024-11-29  14630  14840  14220  14310     -320       -2.19   343664
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 2024-11-27        101.88     -524         -34227                -31
# 2024-11-28        356.37      343          19242                  1
# 2024-11-29         49.47     -376         -25924                 -1
#
#             IndividualNetBuy
# datetime
# 2024-11-27               548
# 2024-11-28              -271
# 2024-11-29               311

# %%
df.iloc[:3,:2]
# Out:
#              Open   High
# datetime
# 2024-11-27  15040  15500
# 2024-11-28  14310  15890
# 2024-11-29  14630  14840

# %%
df.loc[(df.Close>20000),:'Close']
# Out:
#              Open   High    Low  Close
# datetime
# 2025-01-20  20650  22350  19820  20100
# 2025-01-21  20150  21300  19960  20650
# 2025-01-22  20750  20850  20000  20150

# %%
df.loc[(df.Close>15000)&(df.TradingValue>1000)]
# Out:
#              Open   High    Low  Close  Changes  ChangeRate    Volume  \
# datetime
# 2025-01-10  14560  18450  14420  17800     3280       22.59  21280011
# 2025-01-14  16940  20250  16850  18490     1530        9.02  17955440
# 2025-01-20  20650  22350  19820  20100     1290        6.86   7974403
#
#             TradingValue  Program  ForeignNetBuy  InstitutionNetBuy  \
# datetime
# 2025-01-10       3706.61     2070         120867                 -1
# 2025-01-14       3417.44     1893         109466                 13
# 2025-01-20       1684.08      386          24751                -65
#
#             IndividualNetBuy
# datetime
# 2025-01-10             -1995
# 2025-01-14             -1750
# 2025-01-20              -205

# %% [markdown]
# ### multi indexing

# %% [markdown]
# ## Plot

# %%
import matplotlib.pyplot as plt

# %%
df.dtypes
# Out:
# 날짜        object
# 시가        object
# 고가        object
# 저가        object
# 종가        object
# 전일비       object
# 등락률       object
# 거래량       object
# 금액(백만)    object
# 신용비       object
# 개인        object
# 기관        object
# 외인수량      object
# 외국계       object
# 프로그램      object
# 외인비       object
# 외인보유      object
# 외인비중      object
# 외인순매수     object
# 기관순매수     object
# 개인순매수     object
# 신용잔고율     object
# dtype: object

# %%
# DataFrame 컬럼별 데이터 타입 변환

# int로 변환할 컬럼
int_columns = ['시가', '고가', '저가', '종가', '거래량', '금액(백만)']

# 나머지 컬럼은 float로 변환
for column in df.columns:
    if column in int_columns:
        df[column] = df[column].astype(int)  # int로 변환
    else:
        pass

# 변환 후 데이터 타입 확인
df.dtypes
# Out:
# 날짜        object
# 시가         int32
# 고가         int32
# 저가         int32
# 종가         int32
# 전일비       object
# 등락률       object
# 거래량        int32
# 금액(백만)     int32
# 신용비       object
# 개인        object
# 기관        object
# 외인수량      object
# 외국계       object
# 프로그램      object
# 외인비       object
# 외인보유      object
# 외인비중      object
# 외인순매수     object
# 기관순매수     object
# 개인순매수     object
# 신용잔고율     object
# dtype: object

# %%
plt.plot(df['종가'].abs())

# %%
df['종가'].head()
# Out:
# 0    31050
# 1    26600
# 2   -25850
# 3    26400
# 4   -24400
# Name: 종가, dtype: int32

# %%
import time
dfs = []
df = kiwoom.block_request("opt10086",
                          종목코드="161580",
                          기준일자="20250119",
                          표시구분=1,
                          output="일별주가요청",
                          next=1)

dfs.append(df)
a=0
while a<2:
    a = a+1
    df = kiwoom.block_request("opt10086",
                          종목코드="161580",
                          기준일자="20250119",
                          표시구분=1,
                          output="일별주가요청",
                          next=2)
    dfs.append(df)
    time.sleep(1)
    
df = pd.concat(dfs, ignore_index=True)
# Out:
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}
# {'trcode': 'opt10086', 'input': [{'일별주가요청': ['종목코드', '조회일자', '표시구분']}], 'output': [{'일별주가': ['날짜', '시가', '고가', '저가', '종가', '전일비', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인수량', '외국계', '프로그램', '외인비', '외인보유', '외인비중', '외인순매수', '기관순매수', '개인순매수', '신용잔고율']}]}

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Statistics

# %% [markdown]
# #### rolling
# - method provided by Pandas for calculating rolling (or moving) statistics, such as moving averages, over a specified window of time

# %% [markdown]
# DataFrame.rolling(window=N).<aggregation_function>()
# - window=N: Specifies the size of the rolling window (e.g., 10 for a 10-day rolling average)
# - \<aggregation_function\>: The function applied to the rolling window (e.g., .mean(), .sum())

# %%
import pandas as pd

# Example DataFrame
data = {"Close": [30500, 30700, 26500, 27850, 26000, 25750, 24300, 25950, 24500, 20800]}
df = pd.DataFrame(data)

# Compute 10-day moving average
df["10_day_MA"] = df["Close"].rolling(window=5).sum()
print(df)
# Out:
#    Close  10_day_MA
# 0  30500        NaN
# 1  30700        NaN
# 2  26500        NaN
# 3  27850        NaN
# 4  26000   141550.0
# 5  25750   136800.0
# 6  24300   130400.0
# 7  25950   129850.0
# 8  24500   126500.0
# 9  20800   121300.0
